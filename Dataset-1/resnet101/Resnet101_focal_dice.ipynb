# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Resnet101_focal_dice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)


class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-BCE_loss)
        loss = self.alpha * (1 - pt) ** self.gamma * BCE_loss
        return loss.mean()

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        intersection = (inputs * targets).sum(dim=(1,2,3))
        union = inputs.sum(dim=(1,2,3)) + targets.sum(dim=(1,2,3))
        dice = (2. * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice.mean()


class FocalDiceLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.focal = FocalLoss()
        self.dice = DiceLoss()


    def forward(self, inputs, targets):
        return (
            self.focal(inputs, targets) +
            0.5 * self.dice(inputs, targets)

        )

def mean_iou(pred, mask):
    pred = (torch.sigmoid(pred) > 0.5).float()
    inter = (pred * mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter + 1e-6) / (union + 1e-6)).mean()

model = UNet().to(DEVICE)
criterion = FocalDiceLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=1e-5)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f">>> LR changed: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("------------>>> Best model saved <<<-------------\n")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_focal_dice.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal_dice.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:15<00:00, 34.9MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:01<00:00, 160MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:23<00:00,  3.09it/s]
# Epoch 1: Train Loss = 0.3595 | Val Loss = 0.2482 | Val IoU = 0.6894
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 2: Train Loss = 0.2084 | Val Loss = 0.1634 | Val IoU = 0.7181
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 3: Train Loss = 0.1605 | Val Loss = 0.1365 | Val IoU = 0.7519
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 4: Train Loss = 0.1287 | Val Loss = 0.1205 | Val IoU = 0.7690
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 5: Train Loss = 0.1190 | Val Loss = 0.1126 | Val IoU = 0.7792
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 6: Train Loss = 0.1054 | Val Loss = 0.1103 | Val IoU = 0.7843
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 7: Train Loss = 0.0993 | Val Loss = 0.1000 | Val IoU = 0.7991
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 8: Train Loss = 0.0923 | Val Loss = 0.0984 | Val IoU = 0.8058
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 9: Train Loss = 0.0873 | Val Loss = 0.0960 | Val IoU = 0.8083
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 10: Train Loss = 0.0825 | Val Loss = 0.0908 | Val IoU = 0.8145
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 11: Train Loss = 0.0785 | Val Loss = 0.0951 | Val IoU = 0.8075
# Epoch 12/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 12: Train Loss = 0.0814 | Val Loss = 0.0869 | Val IoU = 0.8211
# ------------>>> Best model saved <<<-------------
# Epoch 13/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 13: Train Loss = 0.0761 | Val Loss = 0.0892 | Val IoU = 0.8193
# Epoch 14/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 14: Train Loss = 0.0976 | Val Loss = 0.0927 | Val IoU = 0.8175
# Epoch 15/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 15: Train Loss = 0.0768 | Val Loss = 0.0882 | Val IoU = 0.8245
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 16: Train Loss = 0.0720 | Val Loss = 0.0846 | Val IoU = 0.8294
# ------------>>> Best model saved <<<-------------
# Epoch 17/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 17: Train Loss = 0.0678 | Val Loss = 0.0814 | Val IoU = 0.8365
# ------------>>> Best model saved <<<-------------
# Epoch 18/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 18: Train Loss = 0.0666 | Val Loss = 0.0781 | Val IoU = 0.8388
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 19: Train Loss = 0.0645 | Val Loss = 0.0813 | Val IoU = 0.8355
# Epoch 20/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 20: Train Loss = 0.0639 | Val Loss = 0.0778 | Val IoU = 0.8422
# ------------>>> Best model saved <<<-------------
# Epoch 21/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 21: Train Loss = 0.0613 | Val Loss = 0.0732 | Val IoU = 0.8481
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 22: Train Loss = 0.0658 | Val Loss = 0.0822 | Val IoU = 0.8359
# Epoch 23/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 23: Train Loss = 0.0627 | Val Loss = 0.0743 | Val IoU = 0.8477
# Epoch 24/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 24: Train Loss = 0.0625 | Val Loss = 0.0759 | Val IoU = 0.8458
# Epoch 25/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 25: Train Loss = 0.0576 | Val Loss = 0.0719 | Val IoU = 0.8547
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 26: Train Loss = 0.0569 | Val Loss = 0.0710 | Val IoU = 0.8536
# Epoch 27/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 27: Train Loss = 0.0601 | Val Loss = 0.0774 | Val IoU = 0.8433
# Epoch 28/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 28: Train Loss = 0.0614 | Val Loss = 0.0721 | Val IoU = 0.8530
# Epoch 29/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 29: Train Loss = 0.0583 | Val Loss = 0.0749 | Val IoU = 0.8491
# Epoch 30/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 30: Train Loss = 0.0658 | Val Loss = 0.0794 | Val IoU = 0.8400
# Epoch 31/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 31: Train Loss = 0.0637 | Val Loss = 0.0812 | Val IoU = 0.8451
# >>> LR changed: 0.000100 → 0.000050
# Epoch 32/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 32: Train Loss = 0.0562 | Val Loss = 0.0689 | Val IoU = 0.8605
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 33: Train Loss = 0.0510 | Val Loss = 0.0646 | Val IoU = 0.8654
# ------------>>> Best model saved <<<-------------
# Epoch 34/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 34: Train Loss = 0.0495 | Val Loss = 0.0644 | Val IoU = 0.8668
# ------------>>> Best model saved <<<-------------
# Epoch 35/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 35: Train Loss = 0.0484 | Val Loss = 0.0634 | Val IoU = 0.8691
# ------------>>> Best model saved <<<-------------
# Epoch 36/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 36: Train Loss = 0.0474 | Val Loss = 0.0629 | Val IoU = 0.8710
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 37: Train Loss = 0.0465 | Val Loss = 0.0630 | Val IoU = 0.8698
# Epoch 38/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 38: Train Loss = 0.0461 | Val Loss = 0.0619 | Val IoU = 0.8740
# ------------>>> Best model saved <<<-------------
# Epoch 39/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 39: Train Loss = 0.0474 | Val Loss = 0.0605 | Val IoU = 0.8748
# ------------>>> Best model saved <<<-------------
# Epoch 40/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 40: Train Loss = 0.0448 | Val Loss = 0.0600 | Val IoU = 0.8766
# ------------>>> Best model saved <<<-------------
# Epoch 41/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 41: Train Loss = 0.0442 | Val Loss = 0.0606 | Val IoU = 0.8757
# Epoch 42/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 42: Train Loss = 0.0436 | Val Loss = 0.0609 | Val IoU = 0.8753
# Epoch 43/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 43: Train Loss = 0.0433 | Val Loss = 0.0594 | Val IoU = 0.8774
# ------------>>> Best model saved <<<-------------
# Epoch 44/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 44: Train Loss = 0.0431 | Val Loss = 0.0603 | Val IoU = 0.8760
# Epoch 45/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 45: Train Loss = 0.0432 | Val Loss = 0.0616 | Val IoU = 0.8780
# ------------>>> Best model saved <<<-------------
# Epoch 46/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 46: Train Loss = 0.0433 | Val Loss = 0.0582 | Val IoU = 0.8805
# ------------>>> Best model saved <<<-------------
# Epoch 47/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 47: Train Loss = 0.0416 | Val Loss = 0.0576 | Val IoU = 0.8820
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 48: Train Loss = 0.0463 | Val Loss = 0.0633 | Val IoU = 0.8742
# Epoch 49/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 49: Train Loss = 0.0496 | Val Loss = 0.0618 | Val IoU = 0.8762
# Epoch 50/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 50: Train Loss = 0.0436 | Val Loss = 0.0590 | Val IoU = 0.8799
# Epoch 51/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 51: Train Loss = 0.0410 | Val Loss = 0.0581 | Val IoU = 0.8827
# ------------>>> Best model saved <<<-------------
# Epoch 52/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 52: Train Loss = 0.0401 | Val Loss = 0.0574 | Val IoU = 0.8844
# ------------>>> Best model saved <<<-------------
# Epoch 53/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 53: Train Loss = 0.0405 | Val Loss = 0.0570 | Val IoU = 0.8853
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 54: Train Loss = 0.0393 | Val Loss = 0.0575 | Val IoU = 0.8853
# Epoch 55/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 55: Train Loss = 0.0397 | Val Loss = 0.0572 | Val IoU = 0.8864
# ------------>>> Best model saved <<<-------------
# Epoch 56/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 56: Train Loss = 0.0392 | Val Loss = 0.0577 | Val IoU = 0.8841
# Epoch 57/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 57: Train Loss = 0.0408 | Val Loss = 0.0568 | Val IoU = 0.8859
# Epoch 58/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 58: Train Loss = 0.0387 | Val Loss = 0.0561 | Val IoU = 0.8868
# ------------>>> Best model saved <<<-------------
# Epoch 59/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 59: Train Loss = 0.0378 | Val Loss = 0.0552 | Val IoU = 0.8892
# ------------>>> Best model saved <<<-------------
# Epoch 60/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 60: Train Loss = 0.0373 | Val Loss = 0.0552 | Val IoU = 0.8887
# Epoch 61/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 61: Train Loss = 0.0367 | Val Loss = 0.0550 | Val IoU = 0.8885
# Epoch 62/120: 100%|██████████| 258/258 [01:26<00:00,  3.00it/s]
# Epoch 62: Train Loss = 0.0368 | Val Loss = 0.0565 | Val IoU = 0.8876
# Epoch 63/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 63: Train Loss = 0.0361 | Val Loss = 0.0543 | Val IoU = 0.8914
# ------------>>> Best model saved <<<-------------
# Epoch 64/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 64: Train Loss = 0.0362 | Val Loss = 0.0548 | Val IoU = 0.8892
# Epoch 65/120: 100%|██████████| 258/258 [01:26<00:00,  3.00it/s]
# Epoch 65: Train Loss = 0.0368 | Val Loss = 0.0541 | Val IoU = 0.8915
# ------------>>> Best model saved <<<-------------
# Epoch 66/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 66: Train Loss = 0.0356 | Val Loss = 0.0541 | Val IoU = 0.8911
# Epoch 67/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 67: Train Loss = 0.0356 | Val Loss = 0.0534 | Val IoU = 0.8925
# ------------>>> Best model saved <<<-------------
# Epoch 68/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 68: Train Loss = 0.0352 | Val Loss = 0.0545 | Val IoU = 0.8904
# Epoch 69/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 69: Train Loss = 0.0354 | Val Loss = 0.0545 | Val IoU = 0.8918
# Epoch 70/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 70: Train Loss = 0.0389 | Val Loss = 0.0613 | Val IoU = 0.8811
# Epoch 71/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 71: Train Loss = 0.0403 | Val Loss = 0.0563 | Val IoU = 0.8879
# Epoch 72/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 72: Train Loss = 0.0356 | Val Loss = 0.0536 | Val IoU = 0.8928
# ------------>>> Best model saved <<<-------------
# Epoch 73/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 73: Train Loss = 0.0346 | Val Loss = 0.0539 | Val IoU = 0.8938
# ------------>>> Best model saved <<<-------------
# Epoch 74/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 74: Train Loss = 0.0336 | Val Loss = 0.0526 | Val IoU = 0.8960
# ------------>>> Best model saved <<<-------------
# Epoch 75/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 75: Train Loss = 0.0342 | Val Loss = 0.0535 | Val IoU = 0.8932
# Epoch 76/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 76: Train Loss = 0.0343 | Val Loss = 0.0799 | Val IoU = 0.8782
# Epoch 77/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 77: Train Loss = 0.0481 | Val Loss = 0.0576 | Val IoU = 0.8859
# Epoch 78/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 78: Train Loss = 0.0363 | Val Loss = 0.0538 | Val IoU = 0.8935
# Epoch 79/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 79: Train Loss = 0.0346 | Val Loss = 0.0520 | Val IoU = 0.8959
# Epoch 80/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 80: Train Loss = 0.0347 | Val Loss = 0.0529 | Val IoU = 0.8960
# >>> LR changed: 0.000050 → 0.000025
# ------------>>> Best model saved <<<-------------
# Epoch 81/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 81: Train Loss = 0.0328 | Val Loss = 0.0505 | Val IoU = 0.8995
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 82: Train Loss = 0.0318 | Val Loss = 0.0510 | Val IoU = 0.8998
# ------------>>> Best model saved <<<-------------
# Epoch 83/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 83: Train Loss = 0.0312 | Val Loss = 0.0511 | Val IoU = 0.9004
# ------------>>> Best model saved <<<-------------
# Epoch 84/120: 100%|██████████| 258/258 [01:25<00:00,  3.00it/s]
# Epoch 84: Train Loss = 0.0311 | Val Loss = 0.0508 | Val IoU = 0.9007
# ------------>>> Best model saved <<<-------------
# Epoch 85/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 85: Train Loss = 0.0302 | Val Loss = 0.0501 | Val IoU = 0.9016
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 86: Train Loss = 0.0301 | Val Loss = 0.0497 | Val IoU = 0.9025
# ------------>>> Best model saved <<<-------------
# Epoch 87/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 87: Train Loss = 0.0298 | Val Loss = 0.0494 | Val IoU = 0.9033
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 88: Train Loss = 0.0296 | Val Loss = 0.0494 | Val IoU = 0.9031
# Epoch 89/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 89: Train Loss = 0.0292 | Val Loss = 0.0497 | Val IoU = 0.9032
# Epoch 90/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 90: Train Loss = 0.0290 | Val Loss = 0.0491 | Val IoU = 0.9041
# ------------>>> Best model saved <<<-------------
# Epoch 91/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 91: Train Loss = 0.0289 | Val Loss = 0.0487 | Val IoU = 0.9055
# ------------>>> Best model saved <<<-------------
# Epoch 92/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 92: Train Loss = 0.0287 | Val Loss = 0.0485 | Val IoU = 0.9055
# Epoch 93/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 93: Train Loss = 0.0289 | Val Loss = 0.0494 | Val IoU = 0.9046
# Epoch 94/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 94: Train Loss = 0.0307 | Val Loss = 0.0502 | Val IoU = 0.9029
# Epoch 95/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 95: Train Loss = 0.0302 | Val Loss = 0.0495 | Val IoU = 0.9039
# Epoch 96/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 96: Train Loss = 0.0283 | Val Loss = 0.0485 | Val IoU = 0.9064
# ------------>>> Best model saved <<<-------------
# Epoch 97/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 97: Train Loss = 0.0279 | Val Loss = 0.0495 | Val IoU = 0.9045
# Epoch 98/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 98: Train Loss = 0.0279 | Val Loss = 0.0485 | Val IoU = 0.9067
# ------------>>> Best model saved <<<-------------
# Epoch 99/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 99: Train Loss = 0.0278 | Val Loss = 0.0488 | Val IoU = 0.9063
# Epoch 100/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 100: Train Loss = 0.0276 | Val Loss = 0.0489 | Val IoU = 0.9070
# ------------>>> Best model saved <<<-------------
# Epoch 101/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 101: Train Loss = 0.0282 | Val Loss = 0.0482 | Val IoU = 0.9073
# ------------>>> Best model saved <<<-------------
# Epoch 102/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 102: Train Loss = 0.0289 | Val Loss = 0.0496 | Val IoU = 0.9067
# Epoch 103/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 103: Train Loss = 0.0284 | Val Loss = 0.0489 | Val IoU = 0.9068
# Epoch 104/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 104: Train Loss = 0.0302 | Val Loss = 0.0513 | Val IoU = 0.9039
# Epoch 105/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 105: Train Loss = 0.0297 | Val Loss = 0.0475 | Val IoU = 0.9078
# ------------>>> Best model saved <<<-------------
# Epoch 106/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 106: Train Loss = 0.0273 | Val Loss = 0.0477 | Val IoU = 0.9086
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 107: Train Loss = 0.0316 | Val Loss = 0.0528 | Val IoU = 0.9033
# Epoch 108/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 108: Train Loss = 0.0302 | Val Loss = 0.0488 | Val IoU = 0.9080
# Epoch 109/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 109: Train Loss = 0.0275 | Val Loss = 0.0479 | Val IoU = 0.9093
# ------------>>> Best model saved <<<-------------
# Epoch 110/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 110: Train Loss = 0.0266 | Val Loss = 0.0477 | Val IoU = 0.9100
# ------------>>> Best model saved <<<-------------
# Epoch 111/120: 100%|██████████| 258/258 [01:25<00:00,  3.00it/s]
# Epoch 111: Train Loss = 0.0262 | Val Loss = 0.0468 | Val IoU = 0.9106
# ------------>>> Best model saved <<<-------------
# Epoch 112/120: 100%|██████████| 258/258 [01:25<00:00,  3.01it/s]
# Epoch 112: Train Loss = 0.0259 | Val Loss = 0.0479 | Val IoU = 0.9099
# Epoch 113/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 113: Train Loss = 0.0257 | Val Loss = 0.0476 | Val IoU = 0.9104
# Epoch 114/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 114: Train Loss = 0.0264 | Val Loss = 0.0479 | Val IoU = 0.9100
# Epoch 115/120: 100%|██████████| 258/258 [01:25<00:00,  3.00it/s]
# Epoch 115: Train Loss = 0.0260 | Val Loss = 0.0473 | Val IoU = 0.9114
# ------------>>> Best model saved <<<-------------
# Epoch 116/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 116: Train Loss = 0.0255 | Val Loss = 0.0473 | Val IoU = 0.9105
# Epoch 117/120: 100%|██████████| 258/258 [01:24<00:00,  3.04it/s]
# Epoch 117: Train Loss = 0.0256 | Val Loss = 0.0476 | Val IoU = 0.9107
# Epoch 118/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 118: Train Loss = 0.0260 | Val Loss = 0.0471 | Val IoU = 0.9113
# Epoch 119/120: 100%|██████████| 258/258 [01:25<00:00,  3.02it/s]
# Epoch 119: Train Loss = 0.0256 | Val Loss = 0.0478 | Val IoU = 0.9111
# Epoch 120/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 120: Train Loss = 0.0255 | Val Loss = 0.0476 | Val IoU = 0.9106
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9214
# FINAL TEST LOSS:: 0.0411
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
