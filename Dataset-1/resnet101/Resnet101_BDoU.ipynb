# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Resnet101_BDoU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. SETUP ---
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

# Extract dataset
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# --- 2. CONFIG ---
DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- 3. DATASET ---
class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

# --- 4. SPLIT ---
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

# --- 5. MODEL ---
class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

# --- 6. BDoU LOSS


class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()


def mean_iou(pred, mask):
    pred = (torch.sigmoid(pred) > 0.5).float()
    inter = (pred * mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter + 1e-6) / (union + 1e-6)).mean()

# --- 7. TRAIN ---
model = UNet().to(DEVICE)
criterion = BDoULoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=1e-5)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f">>> LR changed: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("------------>>> Best model saved <<<-------------\n")
# --- 8. PLOT GRAPHS ---
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

# --- 9. TEST ---
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

# --- 10. SAVE RESULTS ---
os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            # save all
            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()

            # show + save 20

            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# --- 11. DOWNLOAD ---
# !zip -rq results_BDoU.zip all_test_results sample_outputs

from google.colab import files
files.download("results_BDoU.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:02<00:00, 222MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:02<00:00, 73.5MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:25<00:00,  3.03it/s]
# Epoch 1: Train Loss = 0.8571 | Val Loss = 0.8217 | Val IoU = 0.1361
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:30<00:00,  2.84it/s]
# Epoch 2: Train Loss = 0.7790 | Val Loss = 0.7604 | Val IoU = 0.1474
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 3: Train Loss = 0.7503 | Val Loss = 0.7536 | Val IoU = 0.1486
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 4: Train Loss = 0.7310 | Val Loss = 0.7328 | Val IoU = 0.1472
# Epoch 5/120: 100%|██████████| 258/258 [01:29<00:00,  2.89it/s]
# Epoch 5: Train Loss = 0.7139 | Val Loss = 0.7307 | Val IoU = 0.1481
# Epoch 6/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 6: Train Loss = 0.7005 | Val Loss = 0.7154 | Val IoU = 0.1480
# Epoch 7/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 7: Train Loss = 0.6879 | Val Loss = 0.7005 | Val IoU = 0.1502
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 8: Train Loss = 0.6766 | Val Loss = 0.6941 | Val IoU = 0.1494
# Epoch 9/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 9: Train Loss = 0.6657 | Val Loss = 0.6949 | Val IoU = 0.1489
# Epoch 10/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 10: Train Loss = 0.6560 | Val Loss = 0.6844 | Val IoU = 0.1518
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 11: Train Loss = 0.6503 | Val Loss = 0.6790 | Val IoU = 0.1507
# Epoch 12/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 12: Train Loss = 0.6407 | Val Loss = 0.6663 | Val IoU = 0.1507
# Epoch 13/120: 100%|██████████| 258/258 [01:30<00:00,  2.84it/s]
# Epoch 13: Train Loss = 0.6400 | Val Loss = 0.6624 | Val IoU = 0.1513
# Epoch 14/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 14: Train Loss = 0.6296 | Val Loss = 0.6673 | Val IoU = 0.1517
# Epoch 15/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 15: Train Loss = 0.6221 | Val Loss = 0.6576 | Val IoU = 0.1515
# Epoch 16/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 16: Train Loss = 0.6137 | Val Loss = 0.6468 | Val IoU = 0.1508
# >>> LR changed: 0.000100 → 0.000050
# Epoch 17/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 17: Train Loss = 0.5999 | Val Loss = 0.6353 | Val IoU = 0.1508
# Epoch 18/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 18: Train Loss = 0.5925 | Val Loss = 0.6260 | Val IoU = 0.1510
# Epoch 19/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 19: Train Loss = 0.5856 | Val Loss = 0.6236 | Val IoU = 0.1512
# Epoch 20/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 20: Train Loss = 0.5814 | Val Loss = 0.6197 | Val IoU = 0.1516
# Epoch 21/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 21: Train Loss = 0.5780 | Val Loss = 0.6161 | Val IoU = 0.1509
# Epoch 22/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 22: Train Loss = 0.5732 | Val Loss = 0.6251 | Val IoU = 0.1510
# >>> LR changed: 0.000050 → 0.000025
# Epoch 23/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 23: Train Loss = 0.5663 | Val Loss = 0.6044 | Val IoU = 0.1513
# Epoch 24/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 24: Train Loss = 0.5594 | Val Loss = 0.6090 | Val IoU = 0.1516
# Epoch 25/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 25: Train Loss = 0.5547 | Val Loss = 0.5982 | Val IoU = 0.1511
# Epoch 26/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 26: Train Loss = 0.5526 | Val Loss = 0.6006 | Val IoU = 0.1513
# Epoch 27/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 27: Train Loss = 0.5493 | Val Loss = 0.5962 | Val IoU = 0.1515
# Epoch 28/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 28: Train Loss = 0.5482 | Val Loss = 0.5944 | Val IoU = 0.1514
# >>> LR changed: 0.000025 → 0.000013
# Epoch 29/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 29: Train Loss = 0.5433 | Val Loss = 0.5918 | Val IoU = 0.1512
# Epoch 30/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 30: Train Loss = 0.5407 | Val Loss = 0.5870 | Val IoU = 0.1513
# Epoch 31/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 31: Train Loss = 0.5387 | Val Loss = 0.5854 | Val IoU = 0.1515
# Epoch 32/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 32: Train Loss = 0.5363 | Val Loss = 0.5844 | Val IoU = 0.1513
# Epoch 33/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 33: Train Loss = 0.5359 | Val Loss = 0.5842 | Val IoU = 0.1513
# Epoch 34/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 34: Train Loss = 0.5334 | Val Loss = 0.5820 | Val IoU = 0.1515
# >>> LR changed: 0.000013 → 0.000006
# Epoch 35/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 35: Train Loss = 0.5320 | Val Loss = 0.5806 | Val IoU = 0.1514
# Epoch 36/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 36: Train Loss = 0.5312 | Val Loss = 0.5826 | Val IoU = 0.1514
# Epoch 37/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 37: Train Loss = 0.5301 | Val Loss = 0.5805 | Val IoU = 0.1513
# Epoch 38/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 38: Train Loss = 0.5290 | Val Loss = 0.5823 | Val IoU = 0.1516
# Epoch 39/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 39: Train Loss = 0.5274 | Val Loss = 0.5771 | Val IoU = 0.1513
# Epoch 40/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 40: Train Loss = 0.5268 | Val Loss = 0.5779 | Val IoU = 0.1515
# >>> LR changed: 0.000006 → 0.000003
# Epoch 41/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 41: Train Loss = 0.5259 | Val Loss = 0.5763 | Val IoU = 0.1515
# Epoch 42/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 42: Train Loss = 0.5258 | Val Loss = 0.5767 | Val IoU = 0.1513
# Epoch 43/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 43: Train Loss = 0.5252 | Val Loss = 0.5783 | Val IoU = 0.1515
# Epoch 44/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 44: Train Loss = 0.5249 | Val Loss = 0.5789 | Val IoU = 0.1516
# Epoch 45/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 45: Train Loss = 0.5256 | Val Loss = 0.5748 | Val IoU = 0.1514
# Epoch 46/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 46: Train Loss = 0.5236 | Val Loss = 0.5737 | Val IoU = 0.1514
# >>> LR changed: 0.000003 → 0.000002
# Epoch 47/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 47: Train Loss = 0.5233 | Val Loss = 0.5736 | Val IoU = 0.1515
# Epoch 48/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 48: Train Loss = 0.5236 | Val Loss = 0.5789 | Val IoU = 0.1516
# Epoch 49/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 49: Train Loss = 0.5227 | Val Loss = 0.5798 | Val IoU = 0.1516
# Epoch 50/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 50: Train Loss = 0.5225 | Val Loss = 0.5788 | Val IoU = 0.1514
# Epoch 51/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 51: Train Loss = 0.5225 | Val Loss = 0.5735 | Val IoU = 0.1514
# Epoch 52/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 52: Train Loss = 0.5218 | Val Loss = 0.5766 | Val IoU = 0.1516
# >>> LR changed: 0.000002 → 0.000001
# Epoch 53/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 53: Train Loss = 0.5213 | Val Loss = 0.5764 | Val IoU = 0.1515
# Epoch 54/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 54: Train Loss = 0.5215 | Val Loss = 0.5752 | Val IoU = 0.1515
# Epoch 55/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 55: Train Loss = 0.5218 | Val Loss = 0.5735 | Val IoU = 0.1516
# Epoch 56/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 56: Train Loss = 0.5219 | Val Loss = 0.5720 | Val IoU = 0.1515
# Epoch 57/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 57: Train Loss = 0.5216 | Val Loss = 0.5729 | Val IoU = 0.1514
# Epoch 58/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 58: Train Loss = 0.5208 | Val Loss = 0.5779 | Val IoU = 0.1514
# >>> LR changed: 0.000001 → 0.000000
# Epoch 59/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 59: Train Loss = 0.5212 | Val Loss = 0.5813 | Val IoU = 0.1515
# Epoch 60/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 60: Train Loss = 0.5207 | Val Loss = 0.5720 | Val IoU = 0.1515
# Epoch 61/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 61: Train Loss = 0.5206 | Val Loss = 0.5751 | Val IoU = 0.1515
# Epoch 62/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 62: Train Loss = 0.5215 | Val Loss = 0.5758 | Val IoU = 0.1515
# Epoch 63/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 63: Train Loss = 0.5208 | Val Loss = 0.5719 | Val IoU = 0.1514
# Epoch 64/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 64: Train Loss = 0.5207 | Val Loss = 0.5742 | Val IoU = 0.1515
# >>> LR changed: 0.000000 → 0.000000
# Epoch 65/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 65: Train Loss = 0.5209 | Val Loss = 0.5712 | Val IoU = 0.1515
# Epoch 66/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 66: Train Loss = 0.5210 | Val Loss = 0.5718 | Val IoU = 0.1514
# Epoch 67/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 67: Train Loss = 0.5192 | Val Loss = 0.5723 | Val IoU = 0.1514
# Epoch 68/120: 100%|██████████| 258/258 [01:30<00:00,  2.84it/s]
# Epoch 68: Train Loss = 0.5210 | Val Loss = 0.5785 | Val IoU = 0.1514
# Epoch 69/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 69: Train Loss = 0.5201 | Val Loss = 0.5748 | Val IoU = 0.1516
# Epoch 70/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 70: Train Loss = 0.5212 | Val Loss = 0.5715 | Val IoU = 0.1515
# >>> LR changed: 0.000000 → 0.000000
# Epoch 71/120: 100%|██████████| 258/258 [01:29<00:00,  2.89it/s]
# Epoch 71: Train Loss = 0.5205 | Val Loss = 0.5718 | Val IoU = 0.1514
# Epoch 72/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 72: Train Loss = 0.5209 | Val Loss = 0.5716 | Val IoU = 0.1514
# Epoch 73/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 73: Train Loss = 0.5202 | Val Loss = 0.5735 | Val IoU = 0.1513
# Epoch 74/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 74: Train Loss = 0.5200 | Val Loss = 0.5717 | Val IoU = 0.1514
# Epoch 75/120: 100%|██████████| 258/258 [01:29<00:00,  2.89it/s]
# Epoch 75: Train Loss = 0.5204 | Val Loss = 0.5714 | Val IoU = 0.1514
# Epoch 76/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 76: Train Loss = 0.5202 | Val Loss = 0.5747 | Val IoU = 0.1515
# >>> LR changed: 0.000000 → 0.000000
# Epoch 77/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 77: Train Loss = 0.5200 | Val Loss = 0.5729 | Val IoU = 0.1516
# Epoch 78/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 78: Train Loss = 0.5201 | Val Loss = 0.5715 | Val IoU = 0.1515
# Epoch 79/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 79: Train Loss = 0.5210 | Val Loss = 0.5713 | Val IoU = 0.1515
# Epoch 80/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 80: Train Loss = 0.5199 | Val Loss = 0.5751 | Val IoU = 0.1515
# Epoch 81/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 81: Train Loss = 0.5209 | Val Loss = 0.5725 | Val IoU = 0.1514
# Epoch 82/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 82: Train Loss = 0.5205 | Val Loss = 0.5723 | Val IoU = 0.1515
# >>> LR changed: 0.000000 → 0.000000
# Epoch 83/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 83: Train Loss = 0.5197 | Val Loss = 0.5763 | Val IoU = 0.1515
# Epoch 84/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 84: Train Loss = 0.5204 | Val Loss = 0.5716 | Val IoU = 0.1515
# Epoch 85/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 85: Train Loss = 0.5208 | Val Loss = 0.5801 | Val IoU = 0.1515
# Epoch 86/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 86: Train Loss = 0.5199 | Val Loss = 0.5739 | Val IoU = 0.1515
# Epoch 87/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 87: Train Loss = 0.5209 | Val Loss = 0.5765 | Val IoU = 0.1516
# Epoch 88/120: 100%|██████████| 258/258 [01:29<00:00,  2.89it/s]
# Epoch 88: Train Loss = 0.5198 | Val Loss = 0.5726 | Val IoU = 0.1514
# >>> LR changed: 0.000000 → 0.000000
# Epoch 89/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 89: Train Loss = 0.5197 | Val Loss = 0.5726 | Val IoU = 0.1514
# Epoch 90/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 90: Train Loss = 0.5200 | Val Loss = 0.5728 | Val IoU = 0.1515
# Epoch 91/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 91: Train Loss = 0.5215 | Val Loss = 0.5724 | Val IoU = 0.1515
# Epoch 92/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 92: Train Loss = 0.5197 | Val Loss = 0.5714 | Val IoU = 0.1515
# Epoch 93/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 93: Train Loss = 0.5206 | Val Loss = 0.5712 | Val IoU = 0.1514
# Epoch 94/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 94: Train Loss = 0.5204 | Val Loss = 0.5718 | Val IoU = 0.1515
# Epoch 95/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 95: Train Loss = 0.5202 | Val Loss = 0.5726 | Val IoU = 0.1515
# Epoch 96/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 96: Train Loss = 0.5200 | Val Loss = 0.5717 | Val IoU = 0.1514
# Epoch 97/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 97: Train Loss = 0.5204 | Val Loss = 0.5723 | Val IoU = 0.1515
# Epoch 98/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 98: Train Loss = 0.5201 | Val Loss = 0.5719 | Val IoU = 0.1516
# Epoch 99/120: 100%|██████████| 258/258 [01:30<00:00,  2.85it/s]
# Epoch 99: Train Loss = 0.5201 | Val Loss = 0.5712 | Val IoU = 0.1515
# Epoch 100/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 100: Train Loss = 0.5203 | Val Loss = 0.5723 | Val IoU = 0.1514
# Epoch 101/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 101: Train Loss = 0.5200 | Val Loss = 0.5732 | Val IoU = 0.1516
# Epoch 102/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 102: Train Loss = 0.5197 | Val Loss = 0.5761 | Val IoU = 0.1515
# Epoch 103/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 103: Train Loss = 0.5205 | Val Loss = 0.5753 | Val IoU = 0.1515
# Epoch 104/120: 100%|██████████| 258/258 [01:30<00:00,  2.87it/s]
# Epoch 104: Train Loss = 0.5198 | Val Loss = 0.5724 | Val IoU = 0.1515
# Epoch 105/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 105: Train Loss = 0.5202 | Val Loss = 0.5711 | Val IoU = 0.1515
# Epoch 106/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 106: Train Loss = 0.5203 | Val Loss = 0.5710 | Val IoU = 0.1515
# Epoch 107/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 107: Train Loss = 0.5211 | Val Loss = 0.5729 | Val IoU = 0.1515
# Epoch 108/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 108: Train Loss = 0.5204 | Val Loss = 0.5743 | Val IoU = 0.1516
# Epoch 109/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 109: Train Loss = 0.5204 | Val Loss = 0.5734 | Val IoU = 0.1514
# Epoch 110/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 110: Train Loss = 0.5201 | Val Loss = 0.5716 | Val IoU = 0.1515
# Epoch 111/120: 100%|██████████| 258/258 [01:30<00:00,  2.86it/s]
# Epoch 111: Train Loss = 0.5194 | Val Loss = 0.5718 | Val IoU = 0.1515
# Epoch 112/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 112: Train Loss = 0.5207 | Val Loss = 0.5775 | Val IoU = 0.1515
# Epoch 113/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 113: Train Loss = 0.5202 | Val Loss = 0.5742 | Val IoU = 0.1515
# Epoch 114/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 114: Train Loss = 0.5212 | Val Loss = 0.5735 | Val IoU = 0.1514
# Epoch 115/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 115: Train Loss = 0.5201 | Val Loss = 0.5715 | Val IoU = 0.1514
# Epoch 116/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 116: Train Loss = 0.5201 | Val Loss = 0.5725 | Val IoU = 0.1515
# Epoch 117/120: 100%|██████████| 258/258 [01:29<00:00,  2.88it/s]
# Epoch 117: Train Loss = 0.5216 | Val Loss = 0.5757 | Val IoU = 0.1515
# Epoch 118/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 118: Train Loss = 0.5198 | Val Loss = 0.5729 | Val IoU = 0.1514
# Epoch 119/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 119: Train Loss = 0.5199 | Val Loss = 0.5720 | Val IoU = 0.1515
# Epoch 120/120: 100%|██████████| 258/258 [01:29<00:00,  2.87it/s]
# Epoch 120: Train Loss = 0.5198 | Val Loss = 0.5714 | Val IoU = 0.1515
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.1563
# FINAL TEST LOSS:: 0.6723
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
