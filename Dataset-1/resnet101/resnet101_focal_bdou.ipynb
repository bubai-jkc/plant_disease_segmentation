# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/resnet101_focal_bdou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=1, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce)
        loss = self.alpha * (1 - pt) ** self.gamma * bce

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()

class FocalBDoULoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.focal = FocalLoss()
        self.bdou = BDoULoss()
        self.lambda_bdou = 0.05

    def forward(self, inputs, targets):
        return (
            self.focal(inputs, targets) +
            self.lambda_bdou * self.bdou(inputs, targets)
        )



def mean_iou(pred,mask):
    pred = (torch.sigmoid(pred)>0.5).float()
    inter = (pred*mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter+1e-6)/(union+1e-6)).mean()

model = UNet().to(DEVICE)
criterion = FocalBDoULoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    criterion.lambda_bdou = min(0.05 + epoch * 0.004, 0.40)
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f"\n------>>> LR changed<<<-------\n: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("\n------------>>> Best model saved <<<-------------\n")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_focal_bdou.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal_bdou.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:03<00:00, 171MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:00<00:00, 181MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:21<00:00,  3.18it/s]
# Epoch 1: Train Loss = 0.1654 | Val Loss = 0.1020 | Val IoU = 0.6203
#
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:24<00:00,  3.05it/s]
# Epoch 2: Train Loss = 0.1025 | Val Loss = 0.0879 | Val IoU = 0.7121
#
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:30<00:00,  2.84it/s]
# Epoch 3: Train Loss = 0.0950 | Val Loss = 0.0918 | Val IoU = 0.7205
#
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 4: Train Loss = 0.0890 | Val Loss = 0.0866 | Val IoU = 0.7364
#
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 5: Train Loss = 0.0888 | Val Loss = 0.0883 | Val IoU = 0.7389
#
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 6: Train Loss = 0.0875 | Val Loss = 0.0882 | Val IoU = 0.7622
#
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 7: Train Loss = 0.0890 | Val Loss = 0.0897 | Val IoU = 0.7686
#
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:32<00:00,  2.79it/s]
# Epoch 8: Train Loss = 0.0883 | Val Loss = 0.0892 | Val IoU = 0.7892
#
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 9: Train Loss = 0.0892 | Val Loss = 0.0938 | Val IoU = 0.7887
# Epoch 10/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 10: Train Loss = 0.0897 | Val Loss = 0.0911 | Val IoU = 0.8047
#
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 11: Train Loss = 0.0901 | Val Loss = 0.0940 | Val IoU = 0.8106
#
# ------------>>> Best model saved <<<-------------
# Epoch 12/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 12: Train Loss = 0.0915 | Val Loss = 0.0955 | Val IoU = 0.8143
#
# ------------>>> Best model saved <<<-------------
# Epoch 13/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 13: Train Loss = 0.0949 | Val Loss = 0.1004 | Val IoU = 0.8107
# Epoch 14/120: 100%|██████████| 258/258 [01:32<00:00,  2.79it/s]
# Epoch 14: Train Loss = 0.1011 | Val Loss = 0.1007 | Val IoU = 0.8159
#
# ------------>>> Best model saved <<<-------------
# Epoch 15/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 15: Train Loss = 0.0980 | Val Loss = 0.1021 | Val IoU = 0.8189
#
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 16: Train Loss = 0.0992 | Val Loss = 0.1105 | Val IoU = 0.8097
# Epoch 17/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 17: Train Loss = 0.1001 | Val Loss = 0.1065 | Val IoU = 0.8271
#
# ------------>>> Best model saved <<<-------------
# Epoch 18/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 18: Train Loss = 0.1007 | Val Loss = 0.1058 | Val IoU = 0.8367
#
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [01:34<00:00,  2.74it/s]
# Epoch 19: Train Loss = 0.1011 | Val Loss = 0.1097 | Val IoU = 0.8360
# Epoch 20/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 20: Train Loss = 0.1032 | Val Loss = 0.1119 | Val IoU = 0.8380
#
# ------------>>> Best model saved <<<-------------
# Epoch 21/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 21: Train Loss = 0.1042 | Val Loss = 0.1122 | Val IoU = 0.8401
#
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 22: Train Loss = 0.1060 | Val Loss = 0.1164 | Val IoU = 0.8427
#
# ------------>>> Best model saved <<<-------------
# Epoch 23/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 23: Train Loss = 0.1071 | Val Loss = 0.1203 | Val IoU = 0.8440
#
# ------------>>> Best model saved <<<-------------
# Epoch 24/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 24: Train Loss = 0.1096 | Val Loss = 0.1215 | Val IoU = 0.8421
# Epoch 25/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 25: Train Loss = 0.1091 | Val Loss = 0.1207 | Val IoU = 0.8522
#
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 26: Train Loss = 0.1098 | Val Loss = 0.1210 | Val IoU = 0.8534
#
# ------------>>> Best model saved <<<-------------
# Epoch 27/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 27: Train Loss = 0.1118 | Val Loss = 0.1245 | Val IoU = 0.8528
# Epoch 28/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 28: Train Loss = 0.1133 | Val Loss = 0.1243 | Val IoU = 0.8567
#
# ------------>>> Best model saved <<<-------------
# Epoch 29/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 29: Train Loss = 0.1151 | Val Loss = 0.1282 | Val IoU = 0.8566
# Epoch 30/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 30: Train Loss = 0.1145 | Val Loss = 0.1270 | Val IoU = 0.8635
#
# ------------>>> Best model saved <<<-------------
# Epoch 31/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 31: Train Loss = 0.1159 | Val Loss = 0.1319 | Val IoU = 0.8617
# Epoch 32/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 32: Train Loss = 0.1183 | Val Loss = 0.1322 | Val IoU = 0.8638
#
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 33: Train Loss = 0.1165 | Val Loss = 0.1311 | Val IoU = 0.8682
#
# ------------>>> Best model saved <<<-------------
# Epoch 34/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 34: Train Loss = 0.1178 | Val Loss = 0.1342 | Val IoU = 0.8682
# Epoch 35/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 35: Train Loss = 0.1204 | Val Loss = 0.1375 | Val IoU = 0.8667
# Epoch 36/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 36: Train Loss = 0.1299 | Val Loss = 0.1447 | Val IoU = 0.8615
# Epoch 37/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 37: Train Loss = 0.1224 | Val Loss = 0.1419 | Val IoU = 0.8682
# Epoch 38/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 38: Train Loss = 0.1223 | Val Loss = 0.1413 | Val IoU = 0.8722
#
# ------------>>> Best model saved <<<-------------
# Epoch 39/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 39: Train Loss = 0.1219 | Val Loss = 0.1429 | Val IoU = 0.8730
#
# ------------>>> Best model saved <<<-------------
# Epoch 40/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 40: Train Loss = 0.1220 | Val Loss = 0.1442 | Val IoU = 0.8758
#
# ------------>>> Best model saved <<<-------------
# Epoch 41/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 41: Train Loss = 0.1236 | Val Loss = 0.1478 | Val IoU = 0.8737
# Epoch 42/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 42: Train Loss = 0.1248 | Val Loss = 0.1478 | Val IoU = 0.8768
#
# ------------>>> Best model saved <<<-------------
# Epoch 43/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 43: Train Loss = 0.1256 | Val Loss = 0.1465 | Val IoU = 0.8802
#
# ------------>>> Best model saved <<<-------------
# Epoch 44/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 44: Train Loss = 0.1254 | Val Loss = 0.1539 | Val IoU = 0.8771
# Epoch 45/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 45: Train Loss = 0.1275 | Val Loss = 0.1567 | Val IoU = 0.8785
# Epoch 46/120: 100%|██████████| 258/258 [01:34<00:00,  2.74it/s]
# Epoch 46: Train Loss = 0.1302 | Val Loss = 0.1536 | Val IoU = 0.8820
#
# ------------>>> Best model saved <<<-------------
# Epoch 47/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 47: Train Loss = 0.1287 | Val Loss = 0.1541 | Val IoU = 0.8821
#
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 48: Train Loss = 0.1327 | Val Loss = 0.1763 | Val IoU = 0.8642
# Epoch 49/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 49: Train Loss = 0.1482 | Val Loss = 0.1653 | Val IoU = 0.8775
# Epoch 50/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 50: Train Loss = 0.1342 | Val Loss = 0.1604 | Val IoU = 0.8829
#
# ------------>>> Best model saved <<<-------------
# Epoch 51/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 51: Train Loss = 0.1350 | Val Loss = 0.1700 | Val IoU = 0.8735
# Epoch 52/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 52: Train Loss = 0.1432 | Val Loss = 0.1648 | Val IoU = 0.8828
# Epoch 53/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 53: Train Loss = 0.1349 | Val Loss = 0.1644 | Val IoU = 0.8868
#
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 54: Train Loss = 0.1341 | Val Loss = 0.1643 | Val IoU = 0.8879
#
# ------------>>> Best model saved <<<-------------
# Epoch 55/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 55: Train Loss = 0.1369 | Val Loss = 0.1669 | Val IoU = 0.8889
#
# ------------>>> Best model saved <<<-------------
# Epoch 56/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 56: Train Loss = 0.1354 | Val Loss = 0.1655 | Val IoU = 0.8913
#
# ------------>>> Best model saved <<<-------------
# Epoch 57/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 57: Train Loss = 0.1348 | Val Loss = 0.1722 | Val IoU = 0.8884
# Epoch 58/120: 100%|██████████| 258/258 [01:34<00:00,  2.74it/s]
# Epoch 58: Train Loss = 0.1358 | Val Loss = 0.1689 | Val IoU = 0.8916
#
# ------------>>> Best model saved <<<-------------
# Epoch 59/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 59: Train Loss = 0.1372 | Val Loss = 0.1733 | Val IoU = 0.8905
# Epoch 60/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 60: Train Loss = 0.1387 | Val Loss = 0.1714 | Val IoU = 0.8937
#
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 61: Train Loss = 0.1392 | Val Loss = 0.1745 | Val IoU = 0.8922
# Epoch 62/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 62: Train Loss = 0.1403 | Val Loss = 0.1766 | Val IoU = 0.8911
# Epoch 63/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 63: Train Loss = 0.1403 | Val Loss = 0.1765 | Val IoU = 0.8936
# Epoch 64/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 64: Train Loss = 0.1464 | Val Loss = 0.1807 | Val IoU = 0.8914
# Epoch 65/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 65: Train Loss = 0.1504 | Val Loss = 0.1807 | Val IoU = 0.8942
#
# ------------>>> Best model saved <<<-------------
# Epoch 66/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 66: Train Loss = 0.1441 | Val Loss = 0.1838 | Val IoU = 0.8915
# Epoch 67/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 67: Train Loss = 0.1439 | Val Loss = 0.1816 | Val IoU = 0.8952
#
# ------------>>> Best model saved <<<-------------
# Epoch 68/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 68: Train Loss = 0.1436 | Val Loss = 0.1857 | Val IoU = 0.8953
#
# ------------>>> Best model saved <<<-------------
# Epoch 69/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 69: Train Loss = 0.1451 | Val Loss = 0.1877 | Val IoU = 0.8949
# Epoch 70/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 70: Train Loss = 0.1498 | Val Loss = 0.1921 | Val IoU = 0.8925
# Epoch 71/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 71: Train Loss = 0.1578 | Val Loss = 0.1984 | Val IoU = 0.8888
# Epoch 72/120: 100%|██████████| 258/258 [01:32<00:00,  2.79it/s]
# Epoch 72: Train Loss = 0.1544 | Val Loss = 0.1935 | Val IoU = 0.8947
# Epoch 73/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 73: Train Loss = 0.1544 | Val Loss = 0.1933 | Val IoU = 0.8966
#
# ------------>>> Best model saved <<<-------------
# Epoch 74/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 74: Train Loss = 0.1486 | Val Loss = 0.1937 | Val IoU = 0.8978
#
# ------------>>> Best model saved <<<-------------
# Epoch 75/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 75: Train Loss = 0.1496 | Val Loss = 0.1927 | Val IoU = 0.9005
#
# ------------>>> Best model saved <<<-------------
# Epoch 76/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 76: Train Loss = 0.1496 | Val Loss = 0.1948 | Val IoU = 0.9003
# Epoch 77/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 77: Train Loss = 0.1533 | Val Loss = 0.1942 | Val IoU = 0.9010
#
# ------------>>> Best model saved <<<-------------
# Epoch 78/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 78: Train Loss = 0.1499 | Val Loss = 0.1973 | Val IoU = 0.9019
#
# ------------>>> Best model saved <<<-------------
# Epoch 79/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 79: Train Loss = 0.1528 | Val Loss = 0.2055 | Val IoU = 0.8982
# Epoch 80/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 80: Train Loss = 0.1556 | Val Loss = 0.1991 | Val IoU = 0.9024
#
# ------------>>> Best model saved <<<-------------
# Epoch 81/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 81: Train Loss = 0.1536 | Val Loss = 0.1987 | Val IoU = 0.9029
#
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [01:32<00:00,  2.79it/s]
# Epoch 82: Train Loss = 0.1539 | Val Loss = 0.2019 | Val IoU = 0.9015
# Epoch 83/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 83: Train Loss = 0.1538 | Val Loss = 0.2036 | Val IoU = 0.9027
# Epoch 84/120: 100%|██████████| 258/258 [01:33<00:00,  2.75it/s]
# Epoch 84: Train Loss = 0.1555 | Val Loss = 0.2060 | Val IoU = 0.9028
# Epoch 85/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 85: Train Loss = 0.1554 | Val Loss = 0.2073 | Val IoU = 0.9037
#
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 86: Train Loss = 0.1558 | Val Loss = 0.2074 | Val IoU = 0.9032
# Epoch 87/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 87: Train Loss = 0.1572 | Val Loss = 0.2089 | Val IoU = 0.9042
#
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 88: Train Loss = 0.1581 | Val Loss = 0.2122 | Val IoU = 0.9033
# Epoch 89/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 89: Train Loss = 0.1580 | Val Loss = 0.2128 | Val IoU = 0.9027
# Epoch 90/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 90: Train Loss = 0.1563 | Val Loss = 0.2117 | Val IoU = 0.9033
# Epoch 91/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 91: Train Loss = 0.1576 | Val Loss = 0.2179 | Val IoU = 0.8997
# Epoch 92/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 92: Train Loss = 0.1649 | Val Loss = 0.2082 | Val IoU = 0.9041
# Epoch 93/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 93: Train Loss = 0.1569 | Val Loss = 0.2044 | Val IoU = 0.9064
#
# ------------>>> Best model saved <<<-------------
# Epoch 94/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 94: Train Loss = 0.1546 | Val Loss = 0.2067 | Val IoU = 0.9053
# Epoch 95/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 95: Train Loss = 0.1561 | Val Loss = 0.2056 | Val IoU = 0.9066
#
# ------------>>> Best model saved <<<-------------
# Epoch 96/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 96: Train Loss = 0.1520 | Val Loss = 0.2049 | Val IoU = 0.9055
# Epoch 97/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 97: Train Loss = 0.1494 | Val Loss = 0.2042 | Val IoU = 0.9071
#
# ------------>>> Best model saved <<<-------------
# Epoch 98/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 98: Train Loss = 0.1486 | Val Loss = 0.2026 | Val IoU = 0.9082
#
# ------------>>> Best model saved <<<-------------
# Epoch 99/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 99: Train Loss = 0.1481 | Val Loss = 0.2024 | Val IoU = 0.9084
#
# ------------>>> Best model saved <<<-------------
# Epoch 100/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 100: Train Loss = 0.1473 | Val Loss = 0.2048 | Val IoU = 0.9078
# Epoch 101/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 101: Train Loss = 0.1493 | Val Loss = 0.2035 | Val IoU = 0.9081
# Epoch 102/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 102: Train Loss = 0.1483 | Val Loss = 0.2047 | Val IoU = 0.9081
# Epoch 103/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 103: Train Loss = 0.1450 | Val Loss = 0.2033 | Val IoU = 0.9080
# Epoch 104/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 104: Train Loss = 0.1472 | Val Loss = 0.2126 | Val IoU = 0.9050
# Epoch 105/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 105: Train Loss = 0.1632 | Val Loss = 0.2031 | Val IoU = 0.9075
#
# ------>>> LR changed<<<-------
# : 0.000100 → 0.000050
# Epoch 106/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 106: Train Loss = 0.1420 | Val Loss = 0.1935 | Val IoU = 0.9130
#
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 107: Train Loss = 0.1411 | Val Loss = 0.1980 | Val IoU = 0.9110
# Epoch 108/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 108: Train Loss = 0.1396 | Val Loss = 0.1915 | Val IoU = 0.9140
#
# ------------>>> Best model saved <<<-------------
# Epoch 109/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 109: Train Loss = 0.1319 | Val Loss = 0.1880 | Val IoU = 0.9153
#
# ------------>>> Best model saved <<<-------------
# Epoch 110/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 110: Train Loss = 0.1293 | Val Loss = 0.1890 | Val IoU = 0.9152
# Epoch 111/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 111: Train Loss = 0.1269 | Val Loss = 0.1853 | Val IoU = 0.9173
#
# ------------>>> Best model saved <<<-------------
# Epoch 112/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 112: Train Loss = 0.1257 | Val Loss = 0.1850 | Val IoU = 0.9175
#
# ------------>>> Best model saved <<<-------------
# Epoch 113/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 113: Train Loss = 0.1248 | Val Loss = 0.1844 | Val IoU = 0.9177
#
# ------------>>> Best model saved <<<-------------
# Epoch 114/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 114: Train Loss = 0.1263 | Val Loss = 0.1848 | Val IoU = 0.9177
#
# ------------>>> Best model saved <<<-------------
# Epoch 115/120: 100%|██████████| 258/258 [01:32<00:00,  2.77it/s]
# Epoch 115: Train Loss = 0.1252 | Val Loss = 0.1838 | Val IoU = 0.9177
# Epoch 116/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 116: Train Loss = 0.1226 | Val Loss = 0.1835 | Val IoU = 0.9177
# Epoch 117/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 117: Train Loss = 0.1229 | Val Loss = 0.1826 | Val IoU = 0.9187
#
# ------------>>> Best model saved <<<-------------
# Epoch 118/120: 100%|██████████| 258/258 [01:33<00:00,  2.76it/s]
# Epoch 118: Train Loss = 0.1239 | Val Loss = 0.1835 | Val IoU = 0.9184
# Epoch 119/120: 100%|██████████| 258/258 [01:32<00:00,  2.78it/s]
# Epoch 119: Train Loss = 0.1221 | Val Loss = 0.1830 | Val IoU = 0.9185
# Epoch 120/120: 100%|██████████| 258/258 [01:33<00:00,  2.77it/s]
# Epoch 120: Train Loss = 0.1209 | Val Loss = 0.1811 | Val IoU = 0.9189
#
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9295
# FINAL TEST LOSS:: 0.1686
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
