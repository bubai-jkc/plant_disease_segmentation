# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Dataset-1/resnet101/Resnet101_focal_bdou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce)
        loss = self.alpha * (1 - pt) ** self.gamma * bce

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()

class FocalBDoULoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.focal = FocalLoss()
        self.bdou = BDoULoss()
        self.lambda_bdou = 0.01

    def forward(self, inputs, targets):
        return (
            (1-self.lambda_bdou) * self.focal(inputs, targets) +
            self.lambda_bdou * self.bdou(inputs, targets)
        )

def mean_iou(pred,mask):
    pred = (torch.sigmoid(pred)>0.5).float()
    inter = (pred*mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter+1e-6)/(union+1e-6)).mean()

model = UNet().to(DEVICE)
criterion = FocalBDoULoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    criterion.lambda_bdou = min(0.01 + epoch * 0.004, 0.40)
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f"\n------>>> LR changed<<<-------\n: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("\n------------>>> Best model saved <<<-------------\n")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()
            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_focal_bdou.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal_bdou.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:29<00:00, 18.2MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:00<00:00, 223MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [00:33<00:00,  7.62it/s]
# Epoch 1: Train Loss = 0.0636 | Val Loss = 0.0375 | Val IoU = 0.6106
#
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [00:31<00:00,  8.13it/s]
# Epoch 2: Train Loss = 0.0396 | Val Loss = 0.0340 | Val IoU = 0.6916
#
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [00:31<00:00,  8.15it/s]
# Epoch 3: Train Loss = 0.0392 | Val Loss = 0.0346 | Val IoU = 0.7241
#
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [00:32<00:00,  8.05it/s]
# Epoch 4: Train Loss = 0.0383 | Val Loss = 0.0363 | Val IoU = 0.7424
#
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 5: Train Loss = 0.0408 | Val Loss = 0.0385 | Val IoU = 0.7533
#
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 6: Train Loss = 0.0416 | Val Loss = 0.0427 | Val IoU = 0.7446
# Epoch 7/120: 100%|██████████| 258/258 [00:32<00:00,  8.05it/s]
# Epoch 7: Train Loss = 0.0446 | Val Loss = 0.0434 | Val IoU = 0.7757
#
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 8: Train Loss = 0.0461 | Val Loss = 0.0466 | Val IoU = 0.7853
#
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 9: Train Loss = 0.0482 | Val Loss = 0.0495 | Val IoU = 0.7858
#
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 10: Train Loss = 0.0509 | Val Loss = 0.0513 | Val IoU = 0.7925
#
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 11: Train Loss = 0.0532 | Val Loss = 0.0543 | Val IoU = 0.7959
#
# ------------>>> Best model saved <<<-------------
# Epoch 12/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 12: Train Loss = 0.0552 | Val Loss = 0.0560 | Val IoU = 0.8076
#
# ------------>>> Best model saved <<<-------------
# Epoch 13/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 13: Train Loss = 0.0585 | Val Loss = 0.0607 | Val IoU = 0.8037
# Epoch 14/120: 100%|██████████| 258/258 [00:31<00:00,  8.07it/s]
# Epoch 14: Train Loss = 0.0645 | Val Loss = 0.0641 | Val IoU = 0.7986
# Epoch 15/120: 100%|██████████| 258/258 [00:32<00:00,  7.90it/s]
# Epoch 15: Train Loss = 0.0629 | Val Loss = 0.0643 | Val IoU = 0.8155
#
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [00:32<00:00,  7.93it/s]
# Epoch 16: Train Loss = 0.0646 | Val Loss = 0.0694 | Val IoU = 0.8109
# Epoch 17/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 17: Train Loss = 0.0664 | Val Loss = 0.0692 | Val IoU = 0.8244
#
# ------------>>> Best model saved <<<-------------
# Epoch 18/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 18: Train Loss = 0.0683 | Val Loss = 0.0705 | Val IoU = 0.8280
#
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 19: Train Loss = 0.0698 | Val Loss = 0.0746 | Val IoU = 0.8271
# Epoch 20/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 20: Train Loss = 0.0724 | Val Loss = 0.0785 | Val IoU = 0.8274
# Epoch 21/120: 100%|██████████| 258/258 [00:32<00:00,  7.91it/s]
# Epoch 21: Train Loss = 0.0740 | Val Loss = 0.0780 | Val IoU = 0.8338
#
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 22: Train Loss = 0.0762 | Val Loss = 0.0813 | Val IoU = 0.8386
#
# ------------>>> Best model saved <<<-------------
# Epoch 23/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 23: Train Loss = 0.0780 | Val Loss = 0.0825 | Val IoU = 0.8416
#
# ------------>>> Best model saved <<<-------------
# Epoch 24/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 24: Train Loss = 0.0813 | Val Loss = 0.0870 | Val IoU = 0.8371
# Epoch 25/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 25: Train Loss = 0.0807 | Val Loss = 0.0872 | Val IoU = 0.8465
#
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [00:32<00:00,  7.99it/s]
# Epoch 26: Train Loss = 0.0824 | Val Loss = 0.0885 | Val IoU = 0.8485
#
# ------------>>> Best model saved <<<-------------
# Epoch 27/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 27: Train Loss = 0.0834 | Val Loss = 0.0904 | Val IoU = 0.8473
# Epoch 28/120: 100%|██████████| 258/258 [00:32<00:00,  7.91it/s]
# Epoch 28: Train Loss = 0.0854 | Val Loss = 0.0932 | Val IoU = 0.8506
#
# ------------>>> Best model saved <<<-------------
# Epoch 29/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 29: Train Loss = 0.0894 | Val Loss = 0.0981 | Val IoU = 0.8457
# Epoch 30/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 30: Train Loss = 0.0897 | Val Loss = 0.0969 | Val IoU = 0.8550
#
# ------------>>> Best model saved <<<-------------
# Epoch 31/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 31: Train Loss = 0.0896 | Val Loss = 0.0997 | Val IoU = 0.8578
#
# ------------>>> Best model saved <<<-------------
# Epoch 32/120: 100%|██████████| 258/258 [00:32<00:00,  8.05it/s]
# Epoch 32: Train Loss = 0.0913 | Val Loss = 0.1019 | Val IoU = 0.8599
#
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 33: Train Loss = 0.0913 | Val Loss = 0.1032 | Val IoU = 0.8600
#
# ------------>>> Best model saved <<<-------------
# Epoch 34/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 34: Train Loss = 0.0928 | Val Loss = 0.1042 | Val IoU = 0.8634
#
# ------------>>> Best model saved <<<-------------
# Epoch 35/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 35: Train Loss = 0.0944 | Val Loss = 0.1073 | Val IoU = 0.8640
#
# ------------>>> Best model saved <<<-------------
# Epoch 36/120: 100%|██████████| 258/258 [00:32<00:00,  7.99it/s]
# Epoch 36: Train Loss = 0.0956 | Val Loss = 0.1098 | Val IoU = 0.8644
#
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [00:32<00:00,  8.05it/s]
# Epoch 37: Train Loss = 0.0963 | Val Loss = 0.1099 | Val IoU = 0.8689
#
# ------------>>> Best model saved <<<-------------
# Epoch 38/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 38: Train Loss = 0.0976 | Val Loss = 0.1108 | Val IoU = 0.8716
#
# ------------>>> Best model saved <<<-------------
# Epoch 39/120: 100%|██████████| 258/258 [00:32<00:00,  7.90it/s]
# Epoch 39: Train Loss = 0.0994 | Val Loss = 0.1152 | Val IoU = 0.8654
# Epoch 40/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 40: Train Loss = 0.0990 | Val Loss = 0.1142 | Val IoU = 0.8743
#
# ------------>>> Best model saved <<<-------------
# Epoch 41/120: 100%|██████████| 258/258 [00:32<00:00,  7.99it/s]
# Epoch 41: Train Loss = 0.1021 | Val Loss = 0.1189 | Val IoU = 0.8686
# Epoch 42/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 42: Train Loss = 0.1046 | Val Loss = 0.1199 | Val IoU = 0.8715
# Epoch 43/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 43: Train Loss = 0.1033 | Val Loss = 0.1186 | Val IoU = 0.8779
#
# ------------>>> Best model saved <<<-------------
# Epoch 44/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 44: Train Loss = 0.1033 | Val Loss = 0.1215 | Val IoU = 0.8772
# Epoch 45/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 45: Train Loss = 0.1052 | Val Loss = 0.1258 | Val IoU = 0.8772
# Epoch 46/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 46: Train Loss = 0.1085 | Val Loss = 0.1279 | Val IoU = 0.8727
# Epoch 47/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 47: Train Loss = 0.1071 | Val Loss = 0.1253 | Val IoU = 0.8809
#
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 48: Train Loss = 0.1090 | Val Loss = 0.1379 | Val IoU = 0.8688
# Epoch 49/120: 100%|██████████| 258/258 [00:32<00:00,  7.96it/s]
# Epoch 49: Train Loss = 0.1194 | Val Loss = 0.1348 | Val IoU = 0.8732
# Epoch 50/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 50: Train Loss = 0.1102 | Val Loss = 0.1330 | Val IoU = 0.8803
# Epoch 51/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 51: Train Loss = 0.1102 | Val Loss = 0.1329 | Val IoU = 0.8824
#
# ------------>>> Best model saved <<<-------------
# Epoch 52/120: 100%|██████████| 258/258 [00:32<00:00,  7.99it/s]
# Epoch 52: Train Loss = 0.1105 | Val Loss = 0.1327 | Val IoU = 0.8870
#
# ------------>>> Best model saved <<<-------------
# Epoch 53/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 53: Train Loss = 0.1111 | Val Loss = 0.1347 | Val IoU = 0.8878
#
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 54: Train Loss = 0.1121 | Val Loss = 0.1357 | Val IoU = 0.8874
# Epoch 55/120: 100%|██████████| 258/258 [00:32<00:00,  7.99it/s]
# Epoch 55: Train Loss = 0.1141 | Val Loss = 0.1389 | Val IoU = 0.8863
# Epoch 56/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 56: Train Loss = 0.1144 | Val Loss = 0.1385 | Val IoU = 0.8888
#
# ------------>>> Best model saved <<<-------------
# Epoch 57/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 57: Train Loss = 0.1144 | Val Loss = 0.1408 | Val IoU = 0.8882
# Epoch 58/120: 100%|██████████| 258/258 [00:32<00:00,  7.89it/s]
# Epoch 58: Train Loss = 0.1159 | Val Loss = 0.1419 | Val IoU = 0.8898
#
# ------------>>> Best model saved <<<-------------
# Epoch 59/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 59: Train Loss = 0.1171 | Val Loss = 0.1475 | Val IoU = 0.8846
# Epoch 60/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 60: Train Loss = 0.1184 | Val Loss = 0.1448 | Val IoU = 0.8905
#
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 61: Train Loss = 0.1184 | Val Loss = 0.1464 | Val IoU = 0.8921
#
# ------------>>> Best model saved <<<-------------
# Epoch 62/120: 100%|██████████| 258/258 [00:32<00:00,  7.93it/s]
# Epoch 62: Train Loss = 0.1208 | Val Loss = 0.1473 | Val IoU = 0.8922
#
# ------------>>> Best model saved <<<-------------
# Epoch 63/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 63: Train Loss = 0.1200 | Val Loss = 0.1501 | Val IoU = 0.8922
# Epoch 64/120: 100%|██████████| 258/258 [00:32<00:00,  8.06it/s]
# Epoch 64: Train Loss = 0.1221 | Val Loss = 0.1512 | Val IoU = 0.8927
#
# ------------>>> Best model saved <<<-------------
# Epoch 65/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 65: Train Loss = 0.1234 | Val Loss = 0.1536 | Val IoU = 0.8924
# Epoch 66/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 66: Train Loss = 0.1227 | Val Loss = 0.1566 | Val IoU = 0.8915
# Epoch 67/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 67: Train Loss = 0.1270 | Val Loss = 0.1554 | Val IoU = 0.8944
#
# ------------>>> Best model saved <<<-------------
# Epoch 68/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 68: Train Loss = 0.1249 | Val Loss = 0.1551 | Val IoU = 0.8959
#
# ------------>>> Best model saved <<<-------------
# Epoch 69/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 69: Train Loss = 0.1257 | Val Loss = 0.1607 | Val IoU = 0.8923
# Epoch 70/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 70: Train Loss = 0.1283 | Val Loss = 0.1585 | Val IoU = 0.8961
#
# ------------>>> Best model saved <<<-------------
# Epoch 71/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 71: Train Loss = 0.1262 | Val Loss = 0.1605 | Val IoU = 0.8974
#
# ------------>>> Best model saved <<<-------------
# Epoch 72/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 72: Train Loss = 0.1266 | Val Loss = 0.1605 | Val IoU = 0.8977
#
# ------------>>> Best model saved <<<-------------
# Epoch 73/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 73: Train Loss = 0.1318 | Val Loss = 0.1625 | Val IoU = 0.8971
# Epoch 74/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 74: Train Loss = 0.1289 | Val Loss = 0.1630 | Val IoU = 0.8991
#
# ------------>>> Best model saved <<<-------------
# Epoch 75/120: 100%|██████████| 258/258 [00:32<00:00,  8.04it/s]
# Epoch 75: Train Loss = 0.1304 | Val Loss = 0.1649 | Val IoU = 0.8995
#
# ------------>>> Best model saved <<<-------------
# Epoch 76/120: 100%|██████████| 258/258 [00:32<00:00,  7.96it/s]
# Epoch 76: Train Loss = 0.1342 | Val Loss = 0.1816 | Val IoU = 0.8865
# Epoch 77/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 77: Train Loss = 0.1494 | Val Loss = 0.1695 | Val IoU = 0.8974
# Epoch 78/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 78: Train Loss = 0.1324 | Val Loss = 0.1696 | Val IoU = 0.8991
# Epoch 79/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 79: Train Loss = 0.1328 | Val Loss = 0.1713 | Val IoU = 0.8993
# Epoch 80/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 80: Train Loss = 0.1320 | Val Loss = 0.1708 | Val IoU = 0.9010
#
# ------------>>> Best model saved <<<-------------
# Epoch 81/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 81: Train Loss = 0.1321 | Val Loss = 0.1694 | Val IoU = 0.9025
#
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 82: Train Loss = 0.1329 | Val Loss = 0.1715 | Val IoU = 0.9029
#
# ------------>>> Best model saved <<<-------------
# Epoch 83/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 83: Train Loss = 0.1338 | Val Loss = 0.1733 | Val IoU = 0.9027
# Epoch 84/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 84: Train Loss = 0.1357 | Val Loss = 0.1751 | Val IoU = 0.9024
# Epoch 85/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 85: Train Loss = 0.1353 | Val Loss = 0.1770 | Val IoU = 0.9031
#
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 86: Train Loss = 0.1360 | Val Loss = 0.1787 | Val IoU = 0.9019
# Epoch 87/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 87: Train Loss = 0.1378 | Val Loss = 0.1797 | Val IoU = 0.9032
#
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [00:32<00:00,  8.05it/s]
# Epoch 88: Train Loss = 0.1384 | Val Loss = 0.1836 | Val IoU = 0.9022
# Epoch 89/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 89: Train Loss = 0.1379 | Val Loss = 0.1882 | Val IoU = 0.8984
# Epoch 90/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 90: Train Loss = 0.1382 | Val Loss = 0.1840 | Val IoU = 0.9031
# Epoch 91/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 91: Train Loss = 0.1407 | Val Loss = 0.1846 | Val IoU = 0.9038
#
# ------------>>> Best model saved <<<-------------
# Epoch 92/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 92: Train Loss = 0.1412 | Val Loss = 0.1861 | Val IoU = 0.9048
#
# ------------>>> Best model saved <<<-------------
# Epoch 93/120: 100%|██████████| 258/258 [00:32<00:00,  7.96it/s]
# Epoch 93: Train Loss = 0.1416 | Val Loss = 0.1858 | Val IoU = 0.9050
#
# ------------>>> Best model saved <<<-------------
# Epoch 94/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 94: Train Loss = 0.1426 | Val Loss = 0.1925 | Val IoU = 0.9051
#
# ------------>>> Best model saved <<<-------------
# Epoch 95/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 95: Train Loss = 0.1490 | Val Loss = 0.2015 | Val IoU = 0.8980
# Epoch 96/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 96: Train Loss = 0.1472 | Val Loss = 0.1932 | Val IoU = 0.9044
# Epoch 97/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 97: Train Loss = 0.1446 | Val Loss = 0.1909 | Val IoU = 0.9057
#
# ------------>>> Best model saved <<<-------------
# Epoch 98/120: 100%|██████████| 258/258 [00:32<00:00,  7.91it/s]
# Epoch 98: Train Loss = 0.1443 | Val Loss = 0.1906 | Val IoU = 0.9076
#
# ------------>>> Best model saved <<<-------------
# Epoch 99/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 99: Train Loss = 0.1436 | Val Loss = 0.1914 | Val IoU = 0.9085
#
# ------------>>> Best model saved <<<-------------
# Epoch 100/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 100: Train Loss = 0.1426 | Val Loss = 0.1919 | Val IoU = 0.9081
# Epoch 101/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 101: Train Loss = 0.1438 | Val Loss = 0.1915 | Val IoU = 0.9080
# Epoch 102/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 102: Train Loss = 0.1439 | Val Loss = 0.1917 | Val IoU = 0.9074
# Epoch 103/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 103: Train Loss = 0.1414 | Val Loss = 0.1914 | Val IoU = 0.9077
# Epoch 104/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 104: Train Loss = 0.1425 | Val Loss = 0.1918 | Val IoU = 0.9078
# Epoch 105/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 105: Train Loss = 0.1514 | Val Loss = 0.1917 | Val IoU = 0.9072
#
# ------>>> LR changed<<<-------
# : 0.000100 → 0.000050
# Epoch 106/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 106: Train Loss = 0.1367 | Val Loss = 0.1839 | Val IoU = 0.9119
#
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [00:32<00:00,  8.01it/s]
# Epoch 107: Train Loss = 0.1336 | Val Loss = 0.1836 | Val IoU = 0.9115
# Epoch 108/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 108: Train Loss = 0.1309 | Val Loss = 0.1800 | Val IoU = 0.9137
#
# ------------>>> Best model saved <<<-------------
# Epoch 109/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 109: Train Loss = 0.1256 | Val Loss = 0.1777 | Val IoU = 0.9148
#
# ------------>>> Best model saved <<<-------------
# Epoch 110/120: 100%|██████████| 258/258 [00:32<00:00,  8.03it/s]
# Epoch 110: Train Loss = 0.1238 | Val Loss = 0.1757 | Val IoU = 0.9158
#
# ------------>>> Best model saved <<<-------------
# Epoch 111/120: 100%|██████████| 258/258 [00:32<00:00,  7.88it/s]
# Epoch 111: Train Loss = 0.1221 | Val Loss = 0.1744 | Val IoU = 0.9168
#
# ------------>>> Best model saved <<<-------------
# Epoch 112/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 112: Train Loss = 0.1210 | Val Loss = 0.1746 | Val IoU = 0.9167
# Epoch 113/120: 100%|██████████| 258/258 [00:32<00:00,  8.00it/s]
# Epoch 113: Train Loss = 0.1206 | Val Loss = 0.1737 | Val IoU = 0.9170
#
# ------------>>> Best model saved <<<-------------
# Epoch 114/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 114: Train Loss = 0.1212 | Val Loss = 0.1733 | Val IoU = 0.9173
#
# ------------>>> Best model saved <<<-------------
# Epoch 115/120: 100%|██████████| 258/258 [00:32<00:00,  7.97it/s]
# Epoch 115: Train Loss = 0.1198 | Val Loss = 0.1723 | Val IoU = 0.9179
#
# ------------>>> Best model saved <<<-------------
# Epoch 116/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 116: Train Loss = 0.1188 | Val Loss = 0.1728 | Val IoU = 0.9177
# Epoch 117/120: 100%|██████████| 258/258 [00:32<00:00,  7.95it/s]
# Epoch 117: Train Loss = 0.1196 | Val Loss = 0.1725 | Val IoU = 0.9176
# Epoch 118/120: 100%|██████████| 258/258 [00:32<00:00,  8.02it/s]
# Epoch 118: Train Loss = 0.1196 | Val Loss = 0.1748 | Val IoU = 0.9161
# Epoch 119/120: 100%|██████████| 258/258 [00:32<00:00,  7.98it/s]
# Epoch 119: Train Loss = 0.1182 | Val Loss = 0.1716 | Val IoU = 0.9181
#
# ------------>>> Best model saved <<<-------------
# Epoch 120/120: 100%|██████████| 258/258 [00:32<00:00,  7.94it/s]
# Epoch 120: Train Loss = 0.1172 | Val Loss = 0.1703 | Val IoU = 0.9182
#
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9298
# FINAL TEST LOSS:: 0.1583
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
