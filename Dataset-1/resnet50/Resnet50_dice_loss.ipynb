# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Resnet50_dice_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. SETUP ---
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

# Extract dataset
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# --- 2. CONFIG ---
DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- 3. DATASET ---
class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

# --- 4. SPLIT ---
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

# --- 5. MODEL ---
class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

# --- 6. DICE LOSS

class DiceLoss(nn.Module):
    def __init__(self, smooth=1e-6):
        super().__init__()
        self.smooth = smooth

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        intersection = (inputs * targets).sum(dim=(1,2,3))
        union = inputs.sum(dim=(1,2,3)) + targets.sum(dim=(1,2,3))
        dice = (2. * intersection + self.smooth) / (union + self.smooth)
        return 1 - dice.mean()


def mean_iou(pred, mask):
    pred = (torch.sigmoid(pred) > 0.5).float()
    inter = (pred * mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter + 1e-6) / (union + 1e-6)).mean()

# --- 7. TRAIN ---
model = UNet().to(DEVICE)
criterion = DiceLoss()
optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=1e-5)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f">>> LR changed: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("------------>>> Best model saved <<<-------------\n")
# --- 8. PLOT GRAPHS ---
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

# --- 9. TEST ---
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

# --- 10. SAVE RESULTS ---
os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            # save all
            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()

            # show + save 20

            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# --- 11. DOWNLOAD ---
# !zip -rq results_dice.zip all_test_results sample_outputs

from google.colab import files
files.download("results_dice.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:03<00:00, 150MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 164MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:05<00:00,  3.97it/s]
# Epoch 1: Train Loss = 0.5873 | Val Loss = 0.4307 | Val IoU = 0.5674
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:06<00:00,  3.87it/s]
# Epoch 2: Train Loss = 0.3304 | Val Loss = 0.2392 | Val IoU = 0.6959
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:09<00:00,  3.74it/s]
# Epoch 3: Train Loss = 0.2185 | Val Loss = 0.1944 | Val IoU = 0.7181
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:10<00:00,  3.63it/s]
# Epoch 4: Train Loss = 0.1896 | Val Loss = 0.1757 | Val IoU = 0.7348
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 5: Train Loss = 0.1674 | Val Loss = 0.1602 | Val IoU = 0.7465
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [01:11<00:00,  3.58it/s]
# Epoch 6: Train Loss = 0.1508 | Val Loss = 0.1525 | Val IoU = 0.7558
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 7: Train Loss = 0.1393 | Val Loss = 0.1419 | Val IoU = 0.7693
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 8: Train Loss = 0.1349 | Val Loss = 0.1461 | Val IoU = 0.7632
# Epoch 9/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 9: Train Loss = 0.1312 | Val Loss = 0.1324 | Val IoU = 0.7808
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 10: Train Loss = 0.1209 | Val Loss = 0.1309 | Val IoU = 0.7829
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 11: Train Loss = 0.1163 | Val Loss = 0.1328 | Val IoU = 0.7796
# Epoch 12/120: 100%|██████████| 258/258 [01:12<00:00,  3.58it/s]
# Epoch 12: Train Loss = 0.1180 | Val Loss = 0.1199 | Val IoU = 0.7974
# ------------>>> Best model saved <<<-------------
# Epoch 13/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 13: Train Loss = 0.1081 | Val Loss = 0.1214 | Val IoU = 0.7948
# Epoch 14/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 14: Train Loss = 0.1040 | Val Loss = 0.1191 | Val IoU = 0.7987
# ------------>>> Best model saved <<<-------------
# Epoch 15/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 15: Train Loss = 0.0998 | Val Loss = 0.1123 | Val IoU = 0.8075
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 16: Train Loss = 0.1065 | Val Loss = 0.1318 | Val IoU = 0.7779
# Epoch 17/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 17: Train Loss = 0.1055 | Val Loss = 0.1162 | Val IoU = 0.8014
# Epoch 18/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 18: Train Loss = 0.0976 | Val Loss = 0.1107 | Val IoU = 0.8097
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 19: Train Loss = 0.0950 | Val Loss = 0.1137 | Val IoU = 0.8054
# Epoch 20/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 20: Train Loss = 0.0934 | Val Loss = 0.1114 | Val IoU = 0.8080
# Epoch 21/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 21: Train Loss = 0.0903 | Val Loss = 0.1031 | Val IoU = 0.8217
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 22: Train Loss = 0.0898 | Val Loss = 0.1020 | Val IoU = 0.8225
# ------------>>> Best model saved <<<-------------
# Epoch 23/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 23: Train Loss = 0.0897 | Val Loss = 0.1033 | Val IoU = 0.8205
# Epoch 24/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 24: Train Loss = 0.0884 | Val Loss = 0.1045 | Val IoU = 0.8196
# Epoch 25/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 25: Train Loss = 0.0881 | Val Loss = 0.0999 | Val IoU = 0.8261
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [01:10<00:00,  3.63it/s]
# Epoch 26: Train Loss = 0.0862 | Val Loss = 0.1162 | Val IoU = 0.8011
# Epoch 27/120: 100%|██████████| 258/258 [01:10<00:00,  3.63it/s]
# Epoch 27: Train Loss = 0.0856 | Val Loss = 0.1093 | Val IoU = 0.8137
# Epoch 28/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 28: Train Loss = 0.0876 | Val Loss = 0.1018 | Val IoU = 0.8241
# Epoch 29/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 29: Train Loss = 0.0832 | Val Loss = 0.0978 | Val IoU = 0.8300
# ------------>>> Best model saved <<<-------------
# Epoch 30/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 30: Train Loss = 0.0815 | Val Loss = 0.0980 | Val IoU = 0.8302
# ------------>>> Best model saved <<<-------------
# Epoch 31/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 31: Train Loss = 0.0810 | Val Loss = 0.0973 | Val IoU = 0.8310
# ------------>>> Best model saved <<<-------------
# Epoch 32/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 32: Train Loss = 0.0782 | Val Loss = 0.0946 | Val IoU = 0.8347
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 33: Train Loss = 0.0786 | Val Loss = 0.1419 | Val IoU = 0.7644
# Epoch 34/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 34: Train Loss = 0.0923 | Val Loss = 0.0995 | Val IoU = 0.8272
# Epoch 35/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 35: Train Loss = 0.0821 | Val Loss = 0.0983 | Val IoU = 0.8292
# Epoch 36/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 36: Train Loss = 0.0811 | Val Loss = 0.0943 | Val IoU = 0.8358
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 37: Train Loss = 0.0752 | Val Loss = 0.0943 | Val IoU = 0.8362
# ------------>>> Best model saved <<<-------------
# Epoch 38/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 38: Train Loss = 0.0748 | Val Loss = 0.0907 | Val IoU = 0.8417
# ------------>>> Best model saved <<<-------------
# Epoch 39/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 39: Train Loss = 0.0728 | Val Loss = 0.0889 | Val IoU = 0.8443
# ------------>>> Best model saved <<<-------------
# Epoch 40/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 40: Train Loss = 0.0711 | Val Loss = 0.0881 | Val IoU = 0.8456
# ------------>>> Best model saved <<<-------------
# Epoch 41/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 41: Train Loss = 0.0694 | Val Loss = 0.0873 | Val IoU = 0.8469
# ------------>>> Best model saved <<<-------------
# Epoch 42/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 42: Train Loss = 0.0694 | Val Loss = 0.0897 | Val IoU = 0.8429
# Epoch 43/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 43: Train Loss = 0.0754 | Val Loss = 0.0916 | Val IoU = 0.8405
# Epoch 44/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 44: Train Loss = 0.0716 | Val Loss = 0.0875 | Val IoU = 0.8463
# Epoch 45/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 45: Train Loss = 0.0732 | Val Loss = 0.0885 | Val IoU = 0.8455
# Epoch 46/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 46: Train Loss = 0.0708 | Val Loss = 0.0886 | Val IoU = 0.8445
# Epoch 47/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 47: Train Loss = 0.0744 | Val Loss = 0.0876 | Val IoU = 0.8466
# >>> LR changed: 0.000100 → 0.000050
# Epoch 48/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 48: Train Loss = 0.0679 | Val Loss = 0.0846 | Val IoU = 0.8514
# ------------>>> Best model saved <<<-------------
# Epoch 49/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 49: Train Loss = 0.0645 | Val Loss = 0.0822 | Val IoU = 0.8555
# ------------>>> Best model saved <<<-------------
# Epoch 50/120: 100%|██████████| 258/258 [01:12<00:00,  3.57it/s]
# Epoch 50: Train Loss = 0.0634 | Val Loss = 0.0823 | Val IoU = 0.8555
# ------------>>> Best model saved <<<-------------
# Epoch 51/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 51: Train Loss = 0.0621 | Val Loss = 0.0815 | Val IoU = 0.8566
# ------------>>> Best model saved <<<-------------
# Epoch 52/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 52: Train Loss = 0.0610 | Val Loss = 0.0798 | Val IoU = 0.8591
# ------------>>> Best model saved <<<-------------
# Epoch 53/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 53: Train Loss = 0.0604 | Val Loss = 0.0794 | Val IoU = 0.8598
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 54: Train Loss = 0.0597 | Val Loss = 0.0797 | Val IoU = 0.8597
# Epoch 55/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 55: Train Loss = 0.0585 | Val Loss = 0.0780 | Val IoU = 0.8622
# ------------>>> Best model saved <<<-------------
# Epoch 56/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 56: Train Loss = 0.0580 | Val Loss = 0.0796 | Val IoU = 0.8593
# Epoch 57/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 57: Train Loss = 0.0577 | Val Loss = 0.0782 | Val IoU = 0.8622
# Epoch 58/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 58: Train Loss = 0.0571 | Val Loss = 0.0766 | Val IoU = 0.8648
# ------------>>> Best model saved <<<-------------
# Epoch 59/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 59: Train Loss = 0.0568 | Val Loss = 0.0770 | Val IoU = 0.8642
# Epoch 60/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 60: Train Loss = 0.0563 | Val Loss = 0.0755 | Val IoU = 0.8657
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 61: Train Loss = 0.0562 | Val Loss = 0.0749 | Val IoU = 0.8667
# ------------>>> Best model saved <<<-------------
# Epoch 62/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 62: Train Loss = 0.0558 | Val Loss = 0.0752 | Val IoU = 0.8666
# Epoch 63/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 63: Train Loss = 0.0549 | Val Loss = 0.0738 | Val IoU = 0.8686
# ------------>>> Best model saved <<<-------------
# Epoch 64/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 64: Train Loss = 0.0543 | Val Loss = 0.0745 | Val IoU = 0.8677
# Epoch 65/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 65: Train Loss = 0.0566 | Val Loss = 0.0737 | Val IoU = 0.8682
# Epoch 66/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 66: Train Loss = 0.0543 | Val Loss = 0.0725 | Val IoU = 0.8702
# ------------>>> Best model saved <<<-------------
# Epoch 67/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 67: Train Loss = 0.0533 | Val Loss = 0.0720 | Val IoU = 0.8714
# ------------>>> Best model saved <<<-------------
# Epoch 68/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 68: Train Loss = 0.0532 | Val Loss = 0.0719 | Val IoU = 0.8713
# Epoch 69/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 69: Train Loss = 0.0525 | Val Loss = 0.0716 | Val IoU = 0.8719
# ------------>>> Best model saved <<<-------------
# Epoch 70/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 70: Train Loss = 0.0527 | Val Loss = 0.0720 | Val IoU = 0.8716
# Epoch 71/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 71: Train Loss = 0.0521 | Val Loss = 0.0712 | Val IoU = 0.8730
# ------------>>> Best model saved <<<-------------
# Epoch 72/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 72: Train Loss = 0.0530 | Val Loss = 0.0715 | Val IoU = 0.8722
# Epoch 73/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 73: Train Loss = 0.0519 | Val Loss = 0.0711 | Val IoU = 0.8728
# Epoch 74/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 74: Train Loss = 0.0511 | Val Loss = 0.0721 | Val IoU = 0.8719
# Epoch 75/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 75: Train Loss = 0.0506 | Val Loss = 0.0710 | Val IoU = 0.8730
# Epoch 76/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 76: Train Loss = 0.0506 | Val Loss = 0.0708 | Val IoU = 0.8734
# ------------>>> Best model saved <<<-------------
# Epoch 77/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 77: Train Loss = 0.0506 | Val Loss = 0.0701 | Val IoU = 0.8746
# ------------>>> Best model saved <<<-------------
# Epoch 78/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 78: Train Loss = 0.0504 | Val Loss = 0.0716 | Val IoU = 0.8718
# Epoch 79/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 79: Train Loss = 0.0521 | Val Loss = 0.0718 | Val IoU = 0.8735
# Epoch 80/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 80: Train Loss = 0.0503 | Val Loss = 0.0710 | Val IoU = 0.8743
# Epoch 81/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 81: Train Loss = 0.0493 | Val Loss = 0.0717 | Val IoU = 0.8727
# Epoch 82/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 82: Train Loss = 0.0498 | Val Loss = 0.0697 | Val IoU = 0.8761
# ------------>>> Best model saved <<<-------------
# Epoch 83/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 83: Train Loss = 0.0485 | Val Loss = 0.0685 | Val IoU = 0.8776
# ------------>>> Best model saved <<<-------------
# Epoch 84/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 84: Train Loss = 0.0488 | Val Loss = 0.0683 | Val IoU = 0.8777
# ------------>>> Best model saved <<<-------------
# Epoch 85/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 85: Train Loss = 0.0480 | Val Loss = 0.0681 | Val IoU = 0.8782
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [01:10<00:00,  3.66it/s]
# Epoch 86: Train Loss = 0.0473 | Val Loss = 0.0670 | Val IoU = 0.8801
# ------------>>> Best model saved <<<-------------
# Epoch 87/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 87: Train Loss = 0.0479 | Val Loss = 0.0677 | Val IoU = 0.8786
# Epoch 88/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 88: Train Loss = 0.0472 | Val Loss = 0.0673 | Val IoU = 0.8797
# Epoch 89/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 89: Train Loss = 0.0470 | Val Loss = 0.0683 | Val IoU = 0.8790
# Epoch 90/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 90: Train Loss = 0.0482 | Val Loss = 0.0692 | Val IoU = 0.8778
# Epoch 91/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 91: Train Loss = 0.0469 | Val Loss = 0.0674 | Val IoU = 0.8806
# ------------>>> Best model saved <<<-------------
# Epoch 92/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 92: Train Loss = 0.0460 | Val Loss = 0.0659 | Val IoU = 0.8820
# ------------>>> Best model saved <<<-------------
# Epoch 93/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 93: Train Loss = 0.0467 | Val Loss = 0.0673 | Val IoU = 0.8804
# Epoch 94/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 94: Train Loss = 0.0499 | Val Loss = 0.0680 | Val IoU = 0.8783
# Epoch 95/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 95: Train Loss = 0.0470 | Val Loss = 0.0657 | Val IoU = 0.8828
# ------------>>> Best model saved <<<-------------
# Epoch 96/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 96: Train Loss = 0.0457 | Val Loss = 0.0660 | Val IoU = 0.8830
# ------------>>> Best model saved <<<-------------
# Epoch 97/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 97: Train Loss = 0.0458 | Val Loss = 0.0666 | Val IoU = 0.8821
# Epoch 98/120: 100%|██████████| 258/258 [01:11<00:00,  3.61it/s]
# Epoch 98: Train Loss = 0.0448 | Val Loss = 0.0661 | Val IoU = 0.8824
# Epoch 99/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 99: Train Loss = 0.0460 | Val Loss = 0.0651 | Val IoU = 0.8837
# ------------>>> Best model saved <<<-------------
# Epoch 100/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 100: Train Loss = 0.0472 | Val Loss = 0.0642 | Val IoU = 0.8847
# ------------>>> Best model saved <<<-------------
# Epoch 101/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 101: Train Loss = 0.0447 | Val Loss = 0.0636 | Val IoU = 0.8857
# ------------>>> Best model saved <<<-------------
# Epoch 102/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 102: Train Loss = 0.0440 | Val Loss = 0.0634 | Val IoU = 0.8863
# ------------>>> Best model saved <<<-------------
# Epoch 103/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 103: Train Loss = 0.0433 | Val Loss = 0.0638 | Val IoU = 0.8855
# Epoch 104/120: 100%|██████████| 258/258 [01:11<00:00,  3.60it/s]
# Epoch 104: Train Loss = 0.0436 | Val Loss = 0.0636 | Val IoU = 0.8857
# Epoch 105/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 105: Train Loss = 0.0437 | Val Loss = 0.0637 | Val IoU = 0.8859
# Epoch 106/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 106: Train Loss = 0.0437 | Val Loss = 0.0629 | Val IoU = 0.8871
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 107: Train Loss = 0.0434 | Val Loss = 0.0623 | Val IoU = 0.8881
# ------------>>> Best model saved <<<-------------
# Epoch 108/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 108: Train Loss = 0.0437 | Val Loss = 0.0641 | Val IoU = 0.8856
# Epoch 109/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 109: Train Loss = 0.0435 | Val Loss = 0.0641 | Val IoU = 0.8857
# Epoch 110/120: 100%|██████████| 258/258 [01:11<00:00,  3.59it/s]
# Epoch 110: Train Loss = 0.0435 | Val Loss = 0.0636 | Val IoU = 0.8865
# Epoch 111/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 111: Train Loss = 0.0433 | Val Loss = 0.0634 | Val IoU = 0.8873
# Epoch 112/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 112: Train Loss = 0.0430 | Val Loss = 0.0630 | Val IoU = 0.8873
# Epoch 113/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 113: Train Loss = 0.0426 | Val Loss = 0.0622 | Val IoU = 0.8883
# ------------>>> Best model saved <<<-------------
# Epoch 114/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 114: Train Loss = 0.0426 | Val Loss = 0.0629 | Val IoU = 0.8873
# Epoch 115/120: 100%|██████████| 258/258 [01:11<00:00,  3.62it/s]
# Epoch 115: Train Loss = 0.0428 | Val Loss = 0.0626 | Val IoU = 0.8874
# Epoch 116/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 116: Train Loss = 0.0423 | Val Loss = 0.0634 | Val IoU = 0.8875
# Epoch 117/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 117: Train Loss = 0.0422 | Val Loss = 0.0635 | Val IoU = 0.8865
# Epoch 118/120: 100%|██████████| 258/258 [01:11<00:00,  3.63it/s]
# Epoch 118: Train Loss = 0.0444 | Val Loss = 0.0624 | Val IoU = 0.8880
# Epoch 119/120: 100%|██████████| 258/258 [01:10<00:00,  3.64it/s]
# Epoch 119: Train Loss = 0.0421 | Val Loss = 0.0624 | Val IoU = 0.8892
# ------------>>> Best model saved <<<-------------
# Epoch 120/120: 100%|██████████| 258/258 [01:10<00:00,  3.65it/s]
# Epoch 120: Train Loss = 0.0426 | Val Loss = 0.0615 | Val IoU = 0.8894
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9027
# FINAL TEST LOSS:: 0.0530
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
