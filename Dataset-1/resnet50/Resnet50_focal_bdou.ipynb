# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Leaf%20Disease%20Segmentation%20Dataset/Resnet50_focal_bdou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce)
        loss = self.alpha * (1 - pt) ** self.gamma * bce

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()

class FocalBDoULoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.focal = FocalLoss()
        self.bdou = BDoULoss()
        self.lambda_bdou = 0.01

    def forward(self, inputs, targets):
        return (
            (1-self.lambda_bdou) * self.focal(inputs, targets) +
            self.lambda_bdou * self.bdou(inputs, targets)
        )

def mean_iou(pred,mask):
    pred = (torch.sigmoid(pred)>0.5).float()
    inter = (pred*mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter+1e-6)/(union+1e-6)).mean()

model = UNet().to(DEVICE)
criterion = FocalBDoULoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    criterion.lambda_bdou = min(0.01 + epoch * 0.004, 0.40)
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f"\n------>>> LR changed<<<-------\n: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("\n------------>>> Best model saved <<<-------------\n")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()
            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_focal_bdou.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal_bdou.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:28<00:00, 18.3MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 242MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [00:26<00:00,  9.71it/s]
# Epoch 1: Train Loss = 0.0689 | Val Loss = 0.0372 | Val IoU = 0.6148
#
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [00:25<00:00, 10.26it/s]
# Epoch 2: Train Loss = 0.0420 | Val Loss = 0.0337 | Val IoU = 0.6929
#
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 3: Train Loss = 0.0397 | Val Loss = 0.0385 | Val IoU = 0.7057
#
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [00:25<00:00, 10.31it/s]
# Epoch 4: Train Loss = 0.0405 | Val Loss = 0.0388 | Val IoU = 0.7356
#
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 5: Train Loss = 0.0419 | Val Loss = 0.0404 | Val IoU = 0.7417
#
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [00:24<00:00, 10.34it/s]
# Epoch 6: Train Loss = 0.0435 | Val Loss = 0.0432 | Val IoU = 0.7419
#
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [00:25<00:00, 10.16it/s]
# Epoch 7: Train Loss = 0.0467 | Val Loss = 0.0457 | Val IoU = 0.7634
#
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [00:25<00:00, 10.14it/s]
# Epoch 8: Train Loss = 0.0482 | Val Loss = 0.0486 | Val IoU = 0.7684
#
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [00:25<00:00, 10.22it/s]
# Epoch 9: Train Loss = 0.0502 | Val Loss = 0.0495 | Val IoU = 0.7838
#
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [00:25<00:00, 10.14it/s]
# Epoch 10: Train Loss = 0.0523 | Val Loss = 0.0525 | Val IoU = 0.7815
# Epoch 11/120: 100%|██████████| 258/258 [00:25<00:00, 10.16it/s]
# Epoch 11: Train Loss = 0.0542 | Val Loss = 0.0560 | Val IoU = 0.7878
#
# ------------>>> Best model saved <<<-------------
# Epoch 12/120: 100%|██████████| 258/258 [00:25<00:00,  9.97it/s]
# Epoch 12: Train Loss = 0.0576 | Val Loss = 0.0587 | Val IoU = 0.7920
#
# ------------>>> Best model saved <<<-------------
# Epoch 13/120: 100%|██████████| 258/258 [00:24<00:00, 10.39it/s]
# Epoch 13: Train Loss = 0.0598 | Val Loss = 0.0608 | Val IoU = 0.7981
#
# ------------>>> Best model saved <<<-------------
# Epoch 14/120: 100%|██████████| 258/258 [00:24<00:00, 10.42it/s]
# Epoch 14: Train Loss = 0.0619 | Val Loss = 0.0638 | Val IoU = 0.7940
# Epoch 15/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 15: Train Loss = 0.0642 | Val Loss = 0.0670 | Val IoU = 0.8028
#
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 16: Train Loss = 0.0667 | Val Loss = 0.0699 | Val IoU = 0.8045
#
# ------------>>> Best model saved <<<-------------
# Epoch 17/120: 100%|██████████| 258/258 [00:25<00:00, 10.19it/s]
# Epoch 17: Train Loss = 0.0695 | Val Loss = 0.0724 | Val IoU = 0.8017
# Epoch 18/120: 100%|██████████| 258/258 [00:25<00:00, 10.14it/s]
# Epoch 18: Train Loss = 0.0707 | Val Loss = 0.0741 | Val IoU = 0.8107
#
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [00:24<00:00, 10.37it/s]
# Epoch 19: Train Loss = 0.0726 | Val Loss = 0.0776 | Val IoU = 0.8148
#
# ------------>>> Best model saved <<<-------------
# Epoch 20/120: 100%|██████████| 258/258 [00:25<00:00, 10.11it/s]
# Epoch 20: Train Loss = 0.0745 | Val Loss = 0.0797 | Val IoU = 0.8122
# Epoch 21/120: 100%|██████████| 258/258 [00:25<00:00, 10.11it/s]
# Epoch 21: Train Loss = 0.0766 | Val Loss = 0.0812 | Val IoU = 0.8239
#
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [00:25<00:00, 10.07it/s]
# Epoch 22: Train Loss = 0.0831 | Val Loss = 0.0875 | Val IoU = 0.8069
# Epoch 23/120: 100%|██████████| 258/258 [00:25<00:00, 10.20it/s]
# Epoch 23: Train Loss = 0.0834 | Val Loss = 0.0849 | Val IoU = 0.8315
#
# ------------>>> Best model saved <<<-------------
# Epoch 24/120: 100%|██████████| 258/258 [00:25<00:00, 10.16it/s]
# Epoch 24: Train Loss = 0.0828 | Val Loss = 0.0875 | Val IoU = 0.8330
#
# ------------>>> Best model saved <<<-------------
# Epoch 25/120: 100%|██████████| 258/258 [00:24<00:00, 10.34it/s]
# Epoch 25: Train Loss = 0.0837 | Val Loss = 0.0909 | Val IoU = 0.8333
#
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [00:24<00:00, 10.40it/s]
# Epoch 26: Train Loss = 0.0856 | Val Loss = 0.0936 | Val IoU = 0.8359
#
# ------------>>> Best model saved <<<-------------
# Epoch 27/120: 100%|██████████| 258/258 [00:25<00:00, 10.26it/s]
# Epoch 27: Train Loss = 0.0906 | Val Loss = 0.1000 | Val IoU = 0.8214
# Epoch 28/120: 100%|██████████| 258/258 [00:25<00:00, 10.02it/s]
# Epoch 28: Train Loss = 0.0893 | Val Loss = 0.0983 | Val IoU = 0.8370
#
# ------------>>> Best model saved <<<-------------
# Epoch 29/120: 100%|██████████| 258/258 [00:25<00:00, 10.23it/s]
# Epoch 29: Train Loss = 0.0905 | Val Loss = 0.1010 | Val IoU = 0.8369
# Epoch 30/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 30: Train Loss = 0.0929 | Val Loss = 0.1003 | Val IoU = 0.8460
#
# ------------>>> Best model saved <<<-------------
# Epoch 31/120: 100%|██████████| 258/258 [00:25<00:00, 10.00it/s]
# Epoch 31: Train Loss = 0.0927 | Val Loss = 0.1025 | Val IoU = 0.8494
#
# ------------>>> Best model saved <<<-------------
# Epoch 32/120: 100%|██████████| 258/258 [00:25<00:00, 10.32it/s]
# Epoch 32: Train Loss = 0.0941 | Val Loss = 0.1032 | Val IoU = 0.8513
#
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [00:25<00:00, 10.16it/s]
# Epoch 33: Train Loss = 0.0951 | Val Loss = 0.1073 | Val IoU = 0.8515
#
# ------------>>> Best model saved <<<-------------
# Epoch 34/120: 100%|██████████| 258/258 [00:25<00:00,  9.99it/s]
# Epoch 34: Train Loss = 0.0962 | Val Loss = 0.1075 | Val IoU = 0.8559
#
# ------------>>> Best model saved <<<-------------
# Epoch 35/120: 100%|██████████| 258/258 [00:25<00:00, 10.23it/s]
# Epoch 35: Train Loss = 0.0974 | Val Loss = 0.1101 | Val IoU = 0.8531
# Epoch 36/120: 100%|██████████| 258/258 [00:25<00:00, 10.23it/s]
# Epoch 36: Train Loss = 0.0990 | Val Loss = 0.1126 | Val IoU = 0.8560
#
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [00:25<00:00, 10.30it/s]
# Epoch 37: Train Loss = 0.1003 | Val Loss = 0.1131 | Val IoU = 0.8609
#
# ------------>>> Best model saved <<<-------------
# Epoch 38/120: 100%|██████████| 258/258 [00:25<00:00, 10.26it/s]
# Epoch 38: Train Loss = 0.1033 | Val Loss = 0.1179 | Val IoU = 0.8560
# Epoch 39/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 39: Train Loss = 0.1125 | Val Loss = 0.1199 | Val IoU = 0.8566
# Epoch 40/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 40: Train Loss = 0.1062 | Val Loss = 0.1205 | Val IoU = 0.8596
# Epoch 41/120: 100%|██████████| 258/258 [00:25<00:00, 10.30it/s]
# Epoch 41: Train Loss = 0.1048 | Val Loss = 0.1205 | Val IoU = 0.8652
#
# ------------>>> Best model saved <<<-------------
# Epoch 42/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 42: Train Loss = 0.1056 | Val Loss = 0.1225 | Val IoU = 0.8659
#
# ------------>>> Best model saved <<<-------------
# Epoch 43/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 43: Train Loss = 0.1063 | Val Loss = 0.1234 | Val IoU = 0.8647
# Epoch 44/120: 100%|██████████| 258/258 [00:25<00:00, 10.23it/s]
# Epoch 44: Train Loss = 0.1073 | Val Loss = 0.1257 | Val IoU = 0.8685
#
# ------------>>> Best model saved <<<-------------
# Epoch 45/120: 100%|██████████| 258/258 [00:25<00:00, 10.21it/s]
# Epoch 45: Train Loss = 0.1083 | Val Loss = 0.1267 | Val IoU = 0.8697
#
# ------------>>> Best model saved <<<-------------
# Epoch 46/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 46: Train Loss = 0.1098 | Val Loss = 0.1312 | Val IoU = 0.8661
# Epoch 47/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 47: Train Loss = 0.1117 | Val Loss = 0.1320 | Val IoU = 0.8703
#
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [00:25<00:00, 10.05it/s]
# Epoch 48: Train Loss = 0.1121 | Val Loss = 0.1346 | Val IoU = 0.8701
# Epoch 49/120: 100%|██████████| 258/258 [00:25<00:00, 10.07it/s]
# Epoch 49: Train Loss = 0.1153 | Val Loss = 0.1607 | Val IoU = 0.8453
# Epoch 50/120: 100%|██████████| 258/258 [00:25<00:00, 10.05it/s]
# Epoch 50: Train Loss = 0.1200 | Val Loss = 0.1383 | Val IoU = 0.8708
#
# ------------>>> Best model saved <<<-------------
# Epoch 51/120: 100%|██████████| 258/258 [00:24<00:00, 10.37it/s]
# Epoch 51: Train Loss = 0.1183 | Val Loss = 0.1412 | Val IoU = 0.8653
# Epoch 52/120: 100%|██████████| 258/258 [00:25<00:00, 10.31it/s]
# Epoch 52: Train Loss = 0.1253 | Val Loss = 0.1393 | Val IoU = 0.8751
#
# ------------>>> Best model saved <<<-------------
# Epoch 53/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 53: Train Loss = 0.1192 | Val Loss = 0.1410 | Val IoU = 0.8765
#
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 54: Train Loss = 0.1191 | Val Loss = 0.1409 | Val IoU = 0.8777
#
# ------------>>> Best model saved <<<-------------
# Epoch 55/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 55: Train Loss = 0.1181 | Val Loss = 0.1430 | Val IoU = 0.8797
#
# ------------>>> Best model saved <<<-------------
# Epoch 56/120: 100%|██████████| 258/258 [00:25<00:00, 10.08it/s]
# Epoch 56: Train Loss = 0.1192 | Val Loss = 0.1439 | Val IoU = 0.8808
#
# ------------>>> Best model saved <<<-------------
# Epoch 57/120: 100%|██████████| 258/258 [00:25<00:00, 10.14it/s]
# Epoch 57: Train Loss = 0.1200 | Val Loss = 0.1484 | Val IoU = 0.8785
# Epoch 58/120: 100%|██████████| 258/258 [00:24<00:00, 10.33it/s]
# Epoch 58: Train Loss = 0.1207 | Val Loss = 0.1486 | Val IoU = 0.8797
# Epoch 59/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 59: Train Loss = 0.1231 | Val Loss = 0.1502 | Val IoU = 0.8800
# Epoch 60/120: 100%|██████████| 258/258 [00:25<00:00, 10.20it/s]
# Epoch 60: Train Loss = 0.1239 | Val Loss = 0.1516 | Val IoU = 0.8829
#
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [00:25<00:00, 10.23it/s]
# Epoch 61: Train Loss = 0.1286 | Val Loss = 0.1533 | Val IoU = 0.8819
# Epoch 62/120: 100%|██████████| 258/258 [00:25<00:00, 10.05it/s]
# Epoch 62: Train Loss = 0.1249 | Val Loss = 0.1545 | Val IoU = 0.8835
#
# ------------>>> Best model saved <<<-------------
# Epoch 63/120: 100%|██████████| 258/258 [00:25<00:00, 10.06it/s]
# Epoch 63: Train Loss = 0.1257 | Val Loss = 0.1548 | Val IoU = 0.8843
#
# ------------>>> Best model saved <<<-------------
# Epoch 64/120: 100%|██████████| 258/258 [00:25<00:00, 10.21it/s]
# Epoch 64: Train Loss = 0.1263 | Val Loss = 0.1563 | Val IoU = 0.8860
#
# ------------>>> Best model saved <<<-------------
# Epoch 65/120: 100%|██████████| 258/258 [00:25<00:00, 10.11it/s]
# Epoch 65: Train Loss = 0.1276 | Val Loss = 0.1588 | Val IoU = 0.8863
#
# ------------>>> Best model saved <<<-------------
# Epoch 66/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 66: Train Loss = 0.1281 | Val Loss = 0.1599 | Val IoU = 0.8862
# Epoch 67/120: 100%|██████████| 258/258 [00:25<00:00, 10.12it/s]
# Epoch 67: Train Loss = 0.1301 | Val Loss = 0.1614 | Val IoU = 0.8860
# Epoch 68/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 68: Train Loss = 0.1294 | Val Loss = 0.1612 | Val IoU = 0.8887
#
# ------------>>> Best model saved <<<-------------
# Epoch 69/120: 100%|██████████| 258/258 [00:25<00:00, 10.08it/s]
# Epoch 69: Train Loss = 0.1307 | Val Loss = 0.1640 | Val IoU = 0.8873
# Epoch 70/120: 100%|██████████| 258/258 [00:25<00:00, 10.30it/s]
# Epoch 70: Train Loss = 0.1306 | Val Loss = 0.1650 | Val IoU = 0.8892
#
# ------------>>> Best model saved <<<-------------
# Epoch 71/120: 100%|██████████| 258/258 [00:25<00:00, 10.31it/s]
# Epoch 71: Train Loss = 0.1324 | Val Loss = 0.1675 | Val IoU = 0.8884
# Epoch 72/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 72: Train Loss = 0.1335 | Val Loss = 0.1660 | Val IoU = 0.8914
#
# ------------>>> Best model saved <<<-------------
# Epoch 73/120: 100%|██████████| 258/258 [00:25<00:00, 10.31it/s]
# Epoch 73: Train Loss = 0.1336 | Val Loss = 0.1698 | Val IoU = 0.8908
# Epoch 74/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 74: Train Loss = 0.1346 | Val Loss = 0.1686 | Val IoU = 0.8931
#
# ------------>>> Best model saved <<<-------------
# Epoch 75/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 75: Train Loss = 0.1345 | Val Loss = 0.1707 | Val IoU = 0.8929
# Epoch 76/120: 100%|██████████| 258/258 [00:25<00:00, 10.19it/s]
# Epoch 76: Train Loss = 0.1358 | Val Loss = 0.1717 | Val IoU = 0.8927
# Epoch 77/120: 100%|██████████| 258/258 [00:25<00:00, 10.31it/s]
# Epoch 77: Train Loss = 0.1365 | Val Loss = 0.1740 | Val IoU = 0.8925
# Epoch 78/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 78: Train Loss = 0.1359 | Val Loss = 0.1755 | Val IoU = 0.8930
# Epoch 79/120: 100%|██████████| 258/258 [00:25<00:00, 10.20it/s]
# Epoch 79: Train Loss = 0.1363 | Val Loss = 0.1745 | Val IoU = 0.8945
#
# ------------>>> Best model saved <<<-------------
# Epoch 80/120: 100%|██████████| 258/258 [00:25<00:00, 10.22it/s]
# Epoch 80: Train Loss = 0.1385 | Val Loss = 0.1777 | Val IoU = 0.8949
#
# ------------>>> Best model saved <<<-------------
# Epoch 81/120: 100%|██████████| 258/258 [00:25<00:00, 10.28it/s]
# Epoch 81: Train Loss = 0.1392 | Val Loss = 0.1786 | Val IoU = 0.8952
#
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 82: Train Loss = 0.1417 | Val Loss = 0.1919 | Val IoU = 0.8853
# Epoch 83/120: 100%|██████████| 258/258 [00:24<00:00, 10.35it/s]
# Epoch 83: Train Loss = 0.1444 | Val Loss = 0.1819 | Val IoU = 0.8946
# Epoch 84/120: 100%|██████████| 258/258 [00:25<00:00, 10.20it/s]
# Epoch 84: Train Loss = 0.1413 | Val Loss = 0.1820 | Val IoU = 0.8955
#
# ------------>>> Best model saved <<<-------------
# Epoch 85/120: 100%|██████████| 258/258 [00:25<00:00, 10.19it/s]
# Epoch 85: Train Loss = 0.1412 | Val Loss = 0.1827 | Val IoU = 0.8973
#
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [00:25<00:00, 10.06it/s]
# Epoch 86: Train Loss = 0.1419 | Val Loss = 0.1845 | Val IoU = 0.8960
# Epoch 87/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 87: Train Loss = 0.1432 | Val Loss = 0.1843 | Val IoU = 0.8983
#
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [00:25<00:00, 10.22it/s]
# Epoch 88: Train Loss = 0.1418 | Val Loss = 0.1850 | Val IoU = 0.8989
#
# ------------>>> Best model saved <<<-------------
# Epoch 89/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 89: Train Loss = 0.1427 | Val Loss = 0.1906 | Val IoU = 0.8970
# Epoch 90/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 90: Train Loss = 0.1427 | Val Loss = 0.1872 | Val IoU = 0.9008
#
# ------------>>> Best model saved <<<-------------
# Epoch 91/120: 100%|██████████| 258/258 [00:25<00:00, 10.12it/s]
# Epoch 91: Train Loss = 0.1435 | Val Loss = 0.1884 | Val IoU = 0.9010
#
# ------------>>> Best model saved <<<-------------
# Epoch 92/120: 100%|██████████| 258/258 [00:24<00:00, 10.34it/s]
# Epoch 92: Train Loss = 0.1448 | Val Loss = 0.1906 | Val IoU = 0.9007
# Epoch 93/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 93: Train Loss = 0.1461 | Val Loss = 0.1944 | Val IoU = 0.8993
# Epoch 94/120: 100%|██████████| 258/258 [00:25<00:00, 10.14it/s]
# Epoch 94: Train Loss = 0.1485 | Val Loss = 0.1930 | Val IoU = 0.9018
#
# ------------>>> Best model saved <<<-------------
# Epoch 95/120: 100%|██████████| 258/258 [00:25<00:00, 10.29it/s]
# Epoch 95: Train Loss = 0.1470 | Val Loss = 0.1958 | Val IoU = 0.9009
# Epoch 96/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 96: Train Loss = 0.1479 | Val Loss = 0.1959 | Val IoU = 0.9008
# Epoch 97/120: 100%|██████████| 258/258 [00:25<00:00, 10.06it/s]
# Epoch 97: Train Loss = 0.1497 | Val Loss = 0.1976 | Val IoU = 0.9016
# Epoch 98/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 98: Train Loss = 0.1489 | Val Loss = 0.1991 | Val IoU = 0.9018
#
# ------------>>> Best model saved <<<-------------
# Epoch 99/120: 100%|██████████| 258/258 [00:24<00:00, 10.36it/s]
# Epoch 99: Train Loss = 0.1502 | Val Loss = 0.1992 | Val IoU = 0.9024
#
# ------------>>> Best model saved <<<-------------
# Epoch 100/120: 100%|██████████| 258/258 [00:25<00:00, 10.10it/s]
# Epoch 100: Train Loss = 0.1551 | Val Loss = 0.2011 | Val IoU = 0.8998
# Epoch 101/120: 100%|██████████| 258/258 [00:25<00:00, 10.09it/s]
# Epoch 101: Train Loss = 0.1465 | Val Loss = 0.1950 | Val IoU = 0.9052
#
# ------------>>> Best model saved <<<-------------
# Epoch 102/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 102: Train Loss = 0.1448 | Val Loss = 0.1954 | Val IoU = 0.9048
# Epoch 103/120: 100%|██████████| 258/258 [00:25<00:00, 10.29it/s]
# Epoch 103: Train Loss = 0.1439 | Val Loss = 0.1928 | Val IoU = 0.9069
#
# ------------>>> Best model saved <<<-------------
# Epoch 104/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 104: Train Loss = 0.1429 | Val Loss = 0.1939 | Val IoU = 0.9052
# Epoch 105/120: 100%|██████████| 258/258 [00:25<00:00, 10.29it/s]
# Epoch 105: Train Loss = 0.1423 | Val Loss = 0.1933 | Val IoU = 0.9060
# Epoch 106/120: 100%|██████████| 258/258 [00:25<00:00, 10.25it/s]
# Epoch 106: Train Loss = 0.1427 | Val Loss = 0.1936 | Val IoU = 0.9064
# Epoch 107/120: 100%|██████████| 258/258 [00:25<00:00, 10.12it/s]
# Epoch 107: Train Loss = 0.1406 | Val Loss = 0.1936 | Val IoU = 0.9064
# Epoch 108/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 108: Train Loss = 0.1401 | Val Loss = 0.1948 | Val IoU = 0.9050
# Epoch 109/120: 100%|██████████| 258/258 [00:25<00:00, 10.09it/s]
# Epoch 109: Train Loss = 0.1410 | Val Loss = 0.1946 | Val IoU = 0.9061
#
# ------>>> LR changed<<<-------
# : 0.000100 → 0.000050
# Epoch 110/120: 100%|██████████| 258/258 [00:25<00:00, 10.24it/s]
# Epoch 110: Train Loss = 0.1351 | Val Loss = 0.1837 | Val IoU = 0.9116
#
# ------------>>> Best model saved <<<-------------
# Epoch 111/120: 100%|██████████| 258/258 [00:25<00:00, 10.27it/s]
# Epoch 111: Train Loss = 0.1301 | Val Loss = 0.1820 | Val IoU = 0.9124
#
# ------------>>> Best model saved <<<-------------
# Epoch 112/120: 100%|██████████| 258/258 [00:25<00:00, 10.10it/s]
# Epoch 112: Train Loss = 0.1266 | Val Loss = 0.1807 | Val IoU = 0.9130
#
# ------------>>> Best model saved <<<-------------
# Epoch 113/120: 100%|██████████| 258/258 [00:25<00:00, 10.18it/s]
# Epoch 113: Train Loss = 0.1252 | Val Loss = 0.1797 | Val IoU = 0.9132
#
# ------------>>> Best model saved <<<-------------
# Epoch 114/120: 100%|██████████| 258/258 [00:25<00:00, 10.21it/s]
# Epoch 114: Train Loss = 0.1233 | Val Loss = 0.1786 | Val IoU = 0.9140
#
# ------------>>> Best model saved <<<-------------
# Epoch 115/120: 100%|██████████| 258/258 [00:25<00:00, 10.15it/s]
# Epoch 115: Train Loss = 0.1224 | Val Loss = 0.1786 | Val IoU = 0.9135
# Epoch 116/120: 100%|██████████| 258/258 [00:24<00:00, 10.39it/s]
# Epoch 116: Train Loss = 0.1212 | Val Loss = 0.1779 | Val IoU = 0.9140
# Epoch 117/120: 100%|██████████| 258/258 [00:25<00:00, 10.17it/s]
# Epoch 117: Train Loss = 0.1215 | Val Loss = 0.1765 | Val IoU = 0.9149
#
# ------------>>> Best model saved <<<-------------
# Epoch 118/120: 100%|██████████| 258/258 [00:25<00:00, 10.19it/s]
# Epoch 118: Train Loss = 0.1203 | Val Loss = 0.1751 | Val IoU = 0.9155
#
# ------------>>> Best model saved <<<-------------
# Epoch 119/120: 100%|██████████| 258/258 [00:25<00:00, 10.16it/s]
# Epoch 119: Train Loss = 0.1197 | Val Loss = 0.1757 | Val IoU = 0.9151
# Epoch 120/120: 100%|██████████| 258/258 [00:25<00:00, 10.29it/s]
# Epoch 120: Train Loss = 0.1193 | Val Loss = 0.1749 | Val IoU = 0.9157
#
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9263
# FINAL TEST LOSS:: 0.1640
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
