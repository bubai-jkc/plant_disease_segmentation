# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Resnet50_focal_BDoU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=1, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce)
        loss = self.alpha * (1 - pt) ** self.gamma * bce

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()

class FocalBDoULoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.focal = FocalLoss()
        self.bdou = BDoULoss()
        self.lambda_bdou = 0.05

    def forward(self, inputs, targets):
        return (
            self.focal(inputs, targets) +
            self.lambda_bdou * self.bdou(inputs, targets)
        )



def mean_iou(pred,mask):
    pred = (torch.sigmoid(pred)>0.5).float()
    inter = (pred*mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter+1e-6)/(union+1e-6)).mean()

model = UNet().to(DEVICE)
criterion = FocalBDoULoss()
optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=5,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    criterion.lambda_bdou = min(0.05 + epoch * 0.004, 0.40)
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f"\n------>>> LR changed<<<-------\n: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("\n------------>>> Best model saved <<<-------------\n")

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_focal_bdou.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal_bdou.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:03<00:00, 172MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 134MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:04<00:00,  3.98it/s]
# Epoch 1: Train Loss = 0.1749 | Val Loss = 0.1047 | Val IoU = 0.6283
#
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:08<00:00,  3.78it/s]
# Epoch 2: Train Loss = 0.1068 | Val Loss = 0.0908 | Val IoU = 0.6828
#
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:15<00:00,  3.42it/s]
# Epoch 3: Train Loss = 0.0955 | Val Loss = 0.0889 | Val IoU = 0.7140
#
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:15<00:00,  3.40it/s]
# Epoch 4: Train Loss = 0.0937 | Val Loss = 0.0882 | Val IoU = 0.7358
#
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 5: Train Loss = 0.0916 | Val Loss = 0.0885 | Val IoU = 0.7409
#
# ------------>>> Best model saved <<<-------------
# Epoch 6/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 6: Train Loss = 0.0913 | Val Loss = 0.0898 | Val IoU = 0.7505
#
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 7: Train Loss = 0.0945 | Val Loss = 0.0965 | Val IoU = 0.7529
#
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 8: Train Loss = 0.0923 | Val Loss = 0.0946 | Val IoU = 0.7730
#
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 9: Train Loss = 0.0943 | Val Loss = 0.0940 | Val IoU = 0.7869
#
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 10: Train Loss = 0.0930 | Val Loss = 0.0950 | Val IoU = 0.7842
# Epoch 11/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 11: Train Loss = 0.0942 | Val Loss = 0.0981 | Val IoU = 0.7958
#
# ------------>>> Best model saved <<<-------------
# Epoch 12/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 12: Train Loss = 0.0970 | Val Loss = 0.0999 | Val IoU = 0.7913
# Epoch 13/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 13: Train Loss = 0.0999 | Val Loss = 0.1076 | Val IoU = 0.7838
# Epoch 14/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 14: Train Loss = 0.1004 | Val Loss = 0.1042 | Val IoU = 0.7964
#
# ------------>>> Best model saved <<<-------------
# Epoch 15/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 15: Train Loss = 0.1005 | Val Loss = 0.1049 | Val IoU = 0.8074
#
# ------------>>> Best model saved <<<-------------
# Epoch 16/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 16: Train Loss = 0.1030 | Val Loss = 0.1097 | Val IoU = 0.8095
#
# ------------>>> Best model saved <<<-------------
# Epoch 17/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 17: Train Loss = 0.1041 | Val Loss = 0.1082 | Val IoU = 0.8129
#
# ------------>>> Best model saved <<<-------------
# Epoch 18/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 18: Train Loss = 0.1046 | Val Loss = 0.1110 | Val IoU = 0.8170
#
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 19: Train Loss = 0.1063 | Val Loss = 0.1152 | Val IoU = 0.8210
#
# ------------>>> Best model saved <<<-------------
# Epoch 20/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 20: Train Loss = 0.1073 | Val Loss = 0.1171 | Val IoU = 0.8186
# Epoch 21/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 21: Train Loss = 0.1093 | Val Loss = 0.1183 | Val IoU = 0.8251
#
# ------------>>> Best model saved <<<-------------
# Epoch 22/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 22: Train Loss = 0.1109 | Val Loss = 0.1192 | Val IoU = 0.8277
#
# ------------>>> Best model saved <<<-------------
# Epoch 23/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 23: Train Loss = 0.1156 | Val Loss = 0.1219 | Val IoU = 0.8318
#
# ------------>>> Best model saved <<<-------------
# Epoch 24/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 24: Train Loss = 0.1159 | Val Loss = 0.1224 | Val IoU = 0.8363
#
# ------------>>> Best model saved <<<-------------
# Epoch 25/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 25: Train Loss = 0.1151 | Val Loss = 0.1273 | Val IoU = 0.8306
# Epoch 26/120: 100%|██████████| 258/258 [01:16<00:00,  3.39it/s]
# Epoch 26: Train Loss = 0.1176 | Val Loss = 0.1336 | Val IoU = 0.8292
# Epoch 27/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 27: Train Loss = 0.1237 | Val Loss = 0.1321 | Val IoU = 0.8353
# Epoch 28/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 28: Train Loss = 0.1226 | Val Loss = 0.1317 | Val IoU = 0.8389
#
# ------------>>> Best model saved <<<-------------
# Epoch 29/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 29: Train Loss = 0.1234 | Val Loss = 0.1348 | Val IoU = 0.8427
#
# ------------>>> Best model saved <<<-------------
# Epoch 30/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 30: Train Loss = 0.1244 | Val Loss = 0.1346 | Val IoU = 0.8477
#
# ------------>>> Best model saved <<<-------------
# Epoch 31/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 31: Train Loss = 0.1229 | Val Loss = 0.1387 | Val IoU = 0.8467
# Epoch 32/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 32: Train Loss = 0.1231 | Val Loss = 0.1369 | Val IoU = 0.8532
#
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 33: Train Loss = 0.1239 | Val Loss = 0.1393 | Val IoU = 0.8537
#
# ------------>>> Best model saved <<<-------------
# Epoch 34/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 34: Train Loss = 0.1245 | Val Loss = 0.1411 | Val IoU = 0.8555
#
# ------------>>> Best model saved <<<-------------
# Epoch 35/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 35: Train Loss = 0.1249 | Val Loss = 0.1418 | Val IoU = 0.8567
#
# ------------>>> Best model saved <<<-------------
# Epoch 36/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 36: Train Loss = 0.1263 | Val Loss = 0.1457 | Val IoU = 0.8574
#
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 37: Train Loss = 0.1274 | Val Loss = 0.1453 | Val IoU = 0.8623
#
# ------------>>> Best model saved <<<-------------
# Epoch 38/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 38: Train Loss = 0.1313 | Val Loss = 0.1498 | Val IoU = 0.8582
# Epoch 39/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 39: Train Loss = 0.1407 | Val Loss = 0.1530 | Val IoU = 0.8575
# Epoch 40/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 40: Train Loss = 0.1330 | Val Loss = 0.1531 | Val IoU = 0.8624
#
# ------------>>> Best model saved <<<-------------
# Epoch 41/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 41: Train Loss = 0.1317 | Val Loss = 0.1527 | Val IoU = 0.8655
#
# ------------>>> Best model saved <<<-------------
# Epoch 42/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 42: Train Loss = 0.1326 | Val Loss = 0.1553 | Val IoU = 0.8656
#
# ------------>>> Best model saved <<<-------------
# Epoch 43/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 43: Train Loss = 0.1331 | Val Loss = 0.1561 | Val IoU = 0.8656
#
# ------------>>> Best model saved <<<-------------
# Epoch 44/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 44: Train Loss = 0.1337 | Val Loss = 0.1612 | Val IoU = 0.8667
#
# ------------>>> Best model saved <<<-------------
# Epoch 45/120: 100%|██████████| 258/258 [01:18<00:00,  3.31it/s]
# Epoch 45: Train Loss = 0.1354 | Val Loss = 0.1602 | Val IoU = 0.8703
#
# ------------>>> Best model saved <<<-------------
# Epoch 46/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 46: Train Loss = 0.1361 | Val Loss = 0.1680 | Val IoU = 0.8620
# Epoch 47/120: 100%|██████████| 258/258 [01:17<00:00,  3.32it/s]
# Epoch 47: Train Loss = 0.1385 | Val Loss = 0.1630 | Val IoU = 0.8711
#
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 48: Train Loss = 0.1378 | Val Loss = 0.1645 | Val IoU = 0.8736
#
# ------------>>> Best model saved <<<-------------
# Epoch 49/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 49: Train Loss = 0.1394 | Val Loss = 0.1662 | Val IoU = 0.8728
# Epoch 50/120: 100%|██████████| 258/258 [01:17<00:00,  3.31it/s]
# Epoch 50: Train Loss = 0.1391 | Val Loss = 0.1678 | Val IoU = 0.8740
#
# ------------>>> Best model saved <<<-------------
# Epoch 51/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 51: Train Loss = 0.1463 | Val Loss = 0.1740 | Val IoU = 0.8684
# Epoch 52/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 52: Train Loss = 0.1475 | Val Loss = 0.1708 | Val IoU = 0.8757
#
# ------------>>> Best model saved <<<-------------
# Epoch 53/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 53: Train Loss = 0.1434 | Val Loss = 0.1707 | Val IoU = 0.8777
#
# ------------>>> Best model saved <<<-------------
# Epoch 54/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 54: Train Loss = 0.1421 | Val Loss = 0.1719 | Val IoU = 0.8791
#
# ------------>>> Best model saved <<<-------------
# Epoch 55/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 55: Train Loss = 0.1423 | Val Loss = 0.1727 | Val IoU = 0.8818
#
# ------------>>> Best model saved <<<-------------
# Epoch 56/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 56: Train Loss = 0.1430 | Val Loss = 0.1771 | Val IoU = 0.8821
#
# ------------>>> Best model saved <<<-------------
# Epoch 57/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 57: Train Loss = 0.1452 | Val Loss = 0.1782 | Val IoU = 0.8813
# Epoch 58/120: 100%|██████████| 258/258 [01:16<00:00,  3.39it/s]
# Epoch 58: Train Loss = 0.1580 | Val Loss = 0.1813 | Val IoU = 0.8797
# Epoch 59/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 59: Train Loss = 0.1488 | Val Loss = 0.1840 | Val IoU = 0.8797
# Epoch 60/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 60: Train Loss = 0.1475 | Val Loss = 0.1828 | Val IoU = 0.8832
#
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 61: Train Loss = 0.1478 | Val Loss = 0.1811 | Val IoU = 0.8862
#
# ------------>>> Best model saved <<<-------------
# Epoch 62/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 62: Train Loss = 0.1476 | Val Loss = 0.1848 | Val IoU = 0.8859
# Epoch 63/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 63: Train Loss = 0.1485 | Val Loss = 0.1843 | Val IoU = 0.8879
#
# ------------>>> Best model saved <<<-------------
# Epoch 64/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 64: Train Loss = 0.1488 | Val Loss = 0.1895 | Val IoU = 0.8866
# Epoch 65/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 65: Train Loss = 0.1516 | Val Loss = 0.1877 | Val IoU = 0.8894
#
# ------------>>> Best model saved <<<-------------
# Epoch 66/120: 100%|██████████| 258/258 [01:16<00:00,  3.39it/s]
# Epoch 66: Train Loss = 0.1508 | Val Loss = 0.1885 | Val IoU = 0.8889
# Epoch 67/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 67: Train Loss = 0.1559 | Val Loss = 0.1953 | Val IoU = 0.8840
# Epoch 68/120: 100%|██████████| 258/258 [01:15<00:00,  3.40it/s]
# Epoch 68: Train Loss = 0.1540 | Val Loss = 0.1916 | Val IoU = 0.8899
#
# ------------>>> Best model saved <<<-------------
# Epoch 69/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 69: Train Loss = 0.1535 | Val Loss = 0.1931 | Val IoU = 0.8904
#
# ------------>>> Best model saved <<<-------------
# Epoch 70/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 70: Train Loss = 0.1532 | Val Loss = 0.1960 | Val IoU = 0.8901
# Epoch 71/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 71: Train Loss = 0.1528 | Val Loss = 0.1950 | Val IoU = 0.8930
#
# ------------>>> Best model saved <<<-------------
# Epoch 72/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 72: Train Loss = 0.1693 | Val Loss = 0.2017 | Val IoU = 0.8885
# Epoch 73/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 73: Train Loss = 0.1589 | Val Loss = 0.1991 | Val IoU = 0.8929
# Epoch 74/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 74: Train Loss = 0.1567 | Val Loss = 0.1981 | Val IoU = 0.8945
#
# ------------>>> Best model saved <<<-------------
# Epoch 75/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 75: Train Loss = 0.1565 | Val Loss = 0.2020 | Val IoU = 0.8945
#
# ------------>>> Best model saved <<<-------------
# Epoch 76/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 76: Train Loss = 0.1567 | Val Loss = 0.2029 | Val IoU = 0.8947
#
# ------------>>> Best model saved <<<-------------
# Epoch 77/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 77: Train Loss = 0.1564 | Val Loss = 0.2014 | Val IoU = 0.8961
#
# ------------>>> Best model saved <<<-------------
# Epoch 78/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 78: Train Loss = 0.1571 | Val Loss = 0.2062 | Val IoU = 0.8947
# Epoch 79/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 79: Train Loss = 0.1579 | Val Loss = 0.2067 | Val IoU = 0.8958
# Epoch 80/120: 100%|██████████| 258/258 [01:16<00:00,  3.39it/s]
# Epoch 80: Train Loss = 0.1627 | Val Loss = 0.2071 | Val IoU = 0.8968
#
# ------------>>> Best model saved <<<-------------
# Epoch 81/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 81: Train Loss = 0.1619 | Val Loss = 0.2098 | Val IoU = 0.8971
#
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 82: Train Loss = 0.1621 | Val Loss = 0.2123 | Val IoU = 0.8953
# Epoch 83/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 83: Train Loss = 0.1619 | Val Loss = 0.2102 | Val IoU = 0.8968
# Epoch 84/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 84: Train Loss = 0.1630 | Val Loss = 0.2148 | Val IoU = 0.8969
# Epoch 85/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 85: Train Loss = 0.1639 | Val Loss = 0.2150 | Val IoU = 0.8983
#
# ------------>>> Best model saved <<<-------------
# Epoch 86/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 86: Train Loss = 0.1648 | Val Loss = 0.2137 | Val IoU = 0.8986
#
# ------------>>> Best model saved <<<-------------
# Epoch 87/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 87: Train Loss = 0.1664 | Val Loss = 0.2173 | Val IoU = 0.8996
#
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 88: Train Loss = 0.1667 | Val Loss = 0.2192 | Val IoU = 0.8977
# Epoch 89/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 89: Train Loss = 0.1649 | Val Loss = 0.2177 | Val IoU = 0.9009
#
# ------------>>> Best model saved <<<-------------
# Epoch 90/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 90: Train Loss = 0.1629 | Val Loss = 0.2157 | Val IoU = 0.9024
#
# ------------>>> Best model saved <<<-------------
# Epoch 91/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 91: Train Loss = 0.1619 | Val Loss = 0.2137 | Val IoU = 0.9020
# Epoch 92/120: 100%|██████████| 258/258 [01:16<00:00,  3.39it/s]
# Epoch 92: Train Loss = 0.1618 | Val Loss = 0.2145 | Val IoU = 0.9009
# Epoch 93/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 93: Train Loss = 0.1599 | Val Loss = 0.2140 | Val IoU = 0.9027
#
# ------------>>> Best model saved <<<-------------
# Epoch 94/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 94: Train Loss = 0.1620 | Val Loss = 0.2121 | Val IoU = 0.9037
#
# ------------>>> Best model saved <<<-------------
# Epoch 95/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 95: Train Loss = 0.1577 | Val Loss = 0.2153 | Val IoU = 0.9017
# Epoch 96/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 96: Train Loss = 0.1569 | Val Loss = 0.2121 | Val IoU = 0.9019
# Epoch 97/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 97: Train Loss = 0.1554 | Val Loss = 0.2121 | Val IoU = 0.9027
# Epoch 98/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 98: Train Loss = 0.1547 | Val Loss = 0.2113 | Val IoU = 0.9037
#
# ------------>>> Best model saved <<<-------------
# Epoch 99/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 99: Train Loss = 0.1564 | Val Loss = 0.2142 | Val IoU = 0.9032
# Epoch 100/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 100: Train Loss = 0.1691 | Val Loss = 0.2141 | Val IoU = 0.8997
#
# ------>>> LR changed<<<-------
# : 0.000100 → 0.000050
# Epoch 101/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 101: Train Loss = 0.1495 | Val Loss = 0.2044 | Val IoU = 0.9056
#
# ------------>>> Best model saved <<<-------------
# Epoch 102/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 102: Train Loss = 0.1438 | Val Loss = 0.2019 | Val IoU = 0.9076
#
# ------------>>> Best model saved <<<-------------
# Epoch 103/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 103: Train Loss = 0.1402 | Val Loss = 0.1991 | Val IoU = 0.9095
#
# ------------>>> Best model saved <<<-------------
# Epoch 104/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 104: Train Loss = 0.1374 | Val Loss = 0.1979 | Val IoU = 0.9104
#
# ------------>>> Best model saved <<<-------------
# Epoch 105/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 105: Train Loss = 0.1365 | Val Loss = 0.1973 | Val IoU = 0.9103
# Epoch 106/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 106: Train Loss = 0.1355 | Val Loss = 0.1959 | Val IoU = 0.9106
#
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 107: Train Loss = 0.1339 | Val Loss = 0.1935 | Val IoU = 0.9121
#
# ------------>>> Best model saved <<<-------------
# Epoch 108/120: 100%|██████████| 258/258 [01:17<00:00,  3.34it/s]
# Epoch 108: Train Loss = 0.1335 | Val Loss = 0.1949 | Val IoU = 0.9115
# Epoch 109/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 109: Train Loss = 0.1321 | Val Loss = 0.1950 | Val IoU = 0.9117
# Epoch 110/120: 100%|██████████| 258/258 [01:17<00:00,  3.35it/s]
# Epoch 110: Train Loss = 0.1319 | Val Loss = 0.1931 | Val IoU = 0.9136
#
# ------------>>> Best model saved <<<-------------
# Epoch 111/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 111: Train Loss = 0.1319 | Val Loss = 0.1934 | Val IoU = 0.9125
# Epoch 112/120: 100%|██████████| 258/258 [01:16<00:00,  3.35it/s]
# Epoch 112: Train Loss = 0.1308 | Val Loss = 0.1942 | Val IoU = 0.9127
# Epoch 113/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 113: Train Loss = 0.1308 | Val Loss = 0.1923 | Val IoU = 0.9130
# Epoch 114/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 114: Train Loss = 0.1291 | Val Loss = 0.1925 | Val IoU = 0.9130
# Epoch 115/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 115: Train Loss = 0.1290 | Val Loss = 0.1924 | Val IoU = 0.9135
# Epoch 116/120: 100%|██████████| 258/258 [01:16<00:00,  3.36it/s]
# Epoch 116: Train Loss = 0.1277 | Val Loss = 0.1941 | Val IoU = 0.9130
#
# ------>>> LR changed<<<-------
# : 0.000050 → 0.000025
# Epoch 117/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 117: Train Loss = 0.1260 | Val Loss = 0.1890 | Val IoU = 0.9155
#
# ------------>>> Best model saved <<<-------------
# Epoch 118/120: 100%|██████████| 258/258 [01:17<00:00,  3.33it/s]
# Epoch 118: Train Loss = 0.1222 | Val Loss = 0.1859 | Val IoU = 0.9165
#
# ------------>>> Best model saved <<<-------------
# Epoch 119/120: 100%|██████████| 258/258 [01:16<00:00,  3.38it/s]
# Epoch 119: Train Loss = 0.1210 | Val Loss = 0.1854 | Val IoU = 0.9168
#
# ------------>>> Best model saved <<<-------------
# Epoch 120/120: 100%|██████████| 258/258 [01:16<00:00,  3.37it/s]
# Epoch 120: Train Loss = 0.1198 | Val Loss = 0.1837 | Val IoU = 0.9181
#
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9289
# FINAL TEST LOSS:: 0.1705
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
