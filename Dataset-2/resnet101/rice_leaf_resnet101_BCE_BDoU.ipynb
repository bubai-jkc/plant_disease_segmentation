# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/Rice-Leaf-Disease-Segmentation-Dataset/resnet101/rice_leaf_resnet101_BCE_BDoU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, torch, random
import numpy as np
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import torchvision.transforms.functional as TF
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim
from tqdm import tqdm
import matplotlib.pyplot as plt
import torch.nn.functional as F


# !git clone https://github.com/ZhouGuoXiong/Rice-Leaf-Disease-Segmentation-Dataset-Code.git


LR = 1e-4
NUM_EPOCHS = 80
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

IMG_DIR = "/content/Rice-Leaf-Disease-Segmentation-Dataset-Code/RICE/VOC2012/JPEGImages"
MASK_DIR = "/content/Rice-Leaf-Disease-Segmentation-Dataset-Code/RICE/VOC2012/SegmentationClass"

TRAIN_TXT = "/content/Rice-Leaf-Disease-Segmentation-Dataset-Code/RICE/VOC2012/ImageSets/Segmentation/train.txt"
VAL_TXT   = "/content/Rice-Leaf-Disease-Segmentation-Dataset-Code/RICE/VOC2012/ImageSets/Segmentation/val.txt"

IMG_SIZE = (256, 256)
BATCH_SIZE = 8

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

def load_split(txt_path):
    with open(txt_path, 'r') as f:
        files = [line.strip() for line in f.readlines()]
    return files

train_list = load_split(TRAIN_TXT)
test_list  = load_split(VAL_TXT)

train_files, val_files = train_test_split(
    train_list,
    test_size=0.15,
    random_state=42
)

class LeafDataset(Dataset):
    def __init__(self, img_dir, mask_dir, file_list, augment=False, img_size=(256, 256)):
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.files = file_list
        self.img_size = img_size
        self.augment = augment

        self.norm = T.Normalize([0.485, 0.456, 0.406],
                                [0.229, 0.224, 0.225])

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]

        img_path = os.path.join(self.img_dir, name + ".jpg")
        mask_path = os.path.join(self.mask_dir, name + ".png")

        img = Image.open(img_path).convert("RGB")
        mask = Image.open(mask_path).convert("L")

        if self.augment:

            if np.random.rand() > 0.5:
                img = TF.hflip(img); mask = TF.hflip(mask)
            if np.random.rand() > 0.5:
                img = TF.vflip(img); mask = TF.vflip(mask)

            angle = np.random.uniform(-30, 30)
            img = TF.rotate(img, angle)
            mask = TF.rotate(mask, angle)

            scale = np.random.uniform(0.8, 1.2)
            tx = int(np.random.uniform(-0.1, 0.1) * img.size[0])
            ty = int(np.random.uniform(-0.1, 0.1) * img.size[1])

            img = TF.affine(img, angle=0, translate=(tx, ty), scale=scale, shear=0)
            mask = TF.affine(mask, angle=0, translate=(tx, ty), scale=scale, shear=0)

            i, j, h, w = T.RandomResizedCrop.get_params(
                img, scale=(0.7, 1.0), ratio=(0.9, 1.1)
            )
            img = TF.resized_crop(img, i, j, h, w, self.img_size)
            mask = TF.resized_crop(mask, i, j, h, w, self.img_size, interpolation=T.InterpolationMode.NEAREST)

            img = T.ColorJitter(
                brightness=0.4,
                contrast=0.4,
                saturation=0.4,
                hue=0.1
            )(img)

            if np.random.rand() > 0.5:
                img = T.GaussianBlur(kernel_size=3)(img)

        else:
            img = TF.resize(img, self.img_size)
            mask = TF.resize(mask, self.img_size, interpolation=T.InterpolationMode.NEAREST)

        img = T.ToTensor()(img)
        img = self.norm(img)

        mask = T.ToTensor()(mask)
        mask = (mask > 0).float()

        return img, mask

train_ds = LeafDataset(IMG_DIR, MASK_DIR, train_files, augment=True)
val_ds   = LeafDataset(IMG_DIR, MASK_DIR, val_files, augment=False)
test_ds  = LeafDataset(IMG_DIR, MASK_DIR, test_list, augment=False)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                          num_workers=2, pin_memory=True)

val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=2, pin_memory=True)

test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=2, pin_memory=True)


class DoubleConv(nn.Module):
    def __init__(self, in_c, out_c, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),

            nn.Dropout2d(dropout) if dropout > 0 else nn.Identity(),

            nn.Conv2d(out_c, out_c, 3, 1, 1, bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.net(x)

class Up(nn.Module):
    def __init__(self, in_c, skip_c, out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c, in_c//2, 2, 2)

        self.conv = DoubleConv(in_c//2 + skip_c, out_c, dropout=0.1)

    def forward(self, x, skip):
        x = self.up(x)
        x = torch.cat([x, skip], 1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet101(weights=models.ResNet101_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

class BDoULoss(nn.Module):
    def __init__(self, alpha_adaptive=0.3, smooth=1e-6):
        super(BDoULoss, self).__init__()
        self.alpha = alpha_adaptive
        self.smooth = smooth

    def get_boundary(self, x):
        max_p = F.max_pool2d(x, 3, 1, 1)
        min_p = -F.max_pool2d(-x, 3, 1, 1)
        return max_p - min_p

    def forward(self, inputs, targets):
        inputs = torch.sigmoid(inputs)
        P = self.get_boundary(inputs)
        G = self.get_boundary(targets)

        intersection = (P * G).sum(dim=(1,2,3))
        union = (P + G).sum(dim=(1,2,3)) - intersection

        loss = (union - intersection + self.smooth) / (union - self.alpha * intersection + self.smooth)
        return loss.mean()


class BceBDoU(nn.Module):
    def __init__(self):
        super().__init__()
        self.bce = nn.BCEWithLogitsLoss()
        self.bdou = BDoULoss()
        self.lambda_bdou = .05

    def forward(self, pred, target):
        bce = self.bce(pred, target)
        bdou = self.bdou(pred, target)
        return bce + self.lambda_bdou * bdou


criterion = BceBDoU()

def mean_iou(pred,mask):
        pred = (torch.sigmoid(pred)>0.5).float()
        inter = (pred*mask).sum((1,2,3))
        union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
        return ((inter+1e-6)/(union+1e-6)).mean()

model = UNet().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=LR,weight_decay=1e-4)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=6,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    criterion.lambda_bdou = min(0.05 + epoch * 0.005, 0.35)
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f">>> LR changed: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("------------>>> Best model saved <<<-------------\n")
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()


            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# !zip -rq results_BCE_BDoU.zip all_test_results sample_outputs

from google.colab import files
files.download("results_BCE_BDoU.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Cloning into 'Rice-Leaf-Disease-Segmentation-Dataset-Code'...
# remote: Enumerating objects: 4629, done.
# remote: Counting objects: 100% (744/744), done.
# remote: Compressing objects: 100% (329/329), done.
# remote: Total 4629 (delta 408), reused 744 (delta 408), pack-reused 3885 (from 1)
# Receiving objects: 100% (4629/4629), 49.62 MiB | 17.34 MiB/s, done.
# Resolving deltas: 100% (1842/1842), done.
# Downloading: "https://download.pytorch.org/models/resnet101-cd907fc2.pth" to /root/.cache/torch/hub/checkpoints/resnet101-cd907fc2.pth
# 100%|██████████| 171M/171M [00:00<00:00, 246MB/s]
# Epoch 1/80: 100%|██████████| 170/170 [00:23<00:00,  7.25it/s]
# Epoch 1: Train Loss = 0.5119 | Val Loss = 0.3018 | Val IoU = 0.4451
# ------------>>> Best model saved <<<-------------
# Epoch 2/80: 100%|██████████| 170/170 [00:21<00:00,  7.98it/s]
# Epoch 2: Train Loss = 0.2043 | Val Loss = 0.1400 | Val IoU = 0.6324
# ------------>>> Best model saved <<<-------------
# Epoch 3/80: 100%|██████████| 170/170 [00:21<00:00,  7.90it/s]
# Epoch 3: Train Loss = 0.1349 | Val Loss = 0.1093 | Val IoU = 0.6664
# ------------>>> Best model saved <<<-------------
# Epoch 4/80: 100%|██████████| 170/170 [00:21<00:00,  7.88it/s]
# Epoch 4: Train Loss = 0.1209 | Val Loss = 0.1009 | Val IoU = 0.6790
# ------------>>> Best model saved <<<-------------
# Epoch 5/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 5: Train Loss = 0.1133 | Val Loss = 0.0984 | Val IoU = 0.6880
# ------------>>> Best model saved <<<-------------
# Epoch 6/80: 100%|██████████| 170/170 [00:21<00:00,  7.88it/s]
# Epoch 6: Train Loss = 0.1131 | Val Loss = 0.1037 | Val IoU = 0.6907
# ------------>>> Best model saved <<<-------------
# Epoch 7/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 7: Train Loss = 0.1132 | Val Loss = 0.1005 | Val IoU = 0.6932
# ------------>>> Best model saved <<<-------------
# Epoch 8/80: 100%|██████████| 170/170 [00:21<00:00,  7.88it/s]
# Epoch 8: Train Loss = 0.1137 | Val Loss = 0.1006 | Val IoU = 0.7032
# ------------>>> Best model saved <<<-------------
# Epoch 9/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 9: Train Loss = 0.1156 | Val Loss = 0.1010 | Val IoU = 0.7187
# ------------>>> Best model saved <<<-------------
# Epoch 10/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 10: Train Loss = 0.1188 | Val Loss = 0.1064 | Val IoU = 0.6901
# Epoch 11/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 11: Train Loss = 0.1219 | Val Loss = 0.1090 | Val IoU = 0.7246
# ------------>>> Best model saved <<<-------------
# Epoch 12/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 12: Train Loss = 0.1221 | Val Loss = 0.1146 | Val IoU = 0.6989
# Epoch 13/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 13: Train Loss = 0.1246 | Val Loss = 0.1115 | Val IoU = 0.7283
# ------------>>> Best model saved <<<-------------
# Epoch 14/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 14: Train Loss = 0.1289 | Val Loss = 0.1155 | Val IoU = 0.7292
# ------------>>> Best model saved <<<-------------
# Epoch 15/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 15: Train Loss = 0.1306 | Val Loss = 0.1177 | Val IoU = 0.7361
# ------------>>> Best model saved <<<-------------
# Epoch 16/80: 100%|██████████| 170/170 [00:21<00:00,  7.87it/s]
# Epoch 16: Train Loss = 0.1339 | Val Loss = 0.1232 | Val IoU = 0.7235
# Epoch 17/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 17: Train Loss = 0.1398 | Val Loss = 0.1285 | Val IoU = 0.7074
# Epoch 18/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 18: Train Loss = 0.1447 | Val Loss = 0.1294 | Val IoU = 0.7250
# Epoch 19/80: 100%|██████████| 170/170 [00:21<00:00,  7.91it/s]
# Epoch 19: Train Loss = 0.1423 | Val Loss = 0.1311 | Val IoU = 0.7225
# Epoch 20/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 20: Train Loss = 0.1449 | Val Loss = 0.1336 | Val IoU = 0.7186
# Epoch 21/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 21: Train Loss = 0.1488 | Val Loss = 0.1372 | Val IoU = 0.7299
# Epoch 22/80: 100%|██████████| 170/170 [00:21<00:00,  7.89it/s]
# Epoch 22: Train Loss = 0.1505 | Val Loss = 0.1395 | Val IoU = 0.7361
# >>> LR changed: 0.000100 → 0.000050
# Epoch 23/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 23: Train Loss = 0.1521 | Val Loss = 0.1400 | Val IoU = 0.7393
# ------------>>> Best model saved <<<-------------
# Epoch 24/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 24: Train Loss = 0.1531 | Val Loss = 0.1445 | Val IoU = 0.7355
# Epoch 25/80: 100%|██████████| 170/170 [00:21<00:00,  7.85it/s]
# Epoch 25: Train Loss = 0.1589 | Val Loss = 0.1476 | Val IoU = 0.7409
# ------------>>> Best model saved <<<-------------
# Epoch 26/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 26: Train Loss = 0.1650 | Val Loss = 0.1486 | Val IoU = 0.7396
# Epoch 27/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 27: Train Loss = 0.1654 | Val Loss = 0.1517 | Val IoU = 0.7466
# ------------>>> Best model saved <<<-------------
# Epoch 28/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 28: Train Loss = 0.1673 | Val Loss = 0.1559 | Val IoU = 0.7392
# Epoch 29/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 29: Train Loss = 0.1702 | Val Loss = 0.1622 | Val IoU = 0.7381
# Epoch 30/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 30: Train Loss = 0.1736 | Val Loss = 0.1649 | Val IoU = 0.7321
# Epoch 31/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 31: Train Loss = 0.1760 | Val Loss = 0.1655 | Val IoU = 0.7373
# Epoch 32/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 32: Train Loss = 0.1783 | Val Loss = 0.1685 | Val IoU = 0.7432
# Epoch 33/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 33: Train Loss = 0.1817 | Val Loss = 0.1720 | Val IoU = 0.7383
# Epoch 34/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 34: Train Loss = 0.1849 | Val Loss = 0.1736 | Val IoU = 0.7458
# >>> LR changed: 0.000050 → 0.000025
# Epoch 35/80: 100%|██████████| 170/170 [00:21<00:00,  7.89it/s]
# Epoch 35: Train Loss = 0.1869 | Val Loss = 0.1772 | Val IoU = 0.7404
# Epoch 36/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 36: Train Loss = 0.1891 | Val Loss = 0.1791 | Val IoU = 0.7485
# ------------>>> Best model saved <<<-------------
# Epoch 37/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 37: Train Loss = 0.1924 | Val Loss = 0.1815 | Val IoU = 0.7506
# ------------>>> Best model saved <<<-------------
# Epoch 38/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 38: Train Loss = 0.1962 | Val Loss = 0.1845 | Val IoU = 0.7499
# Epoch 39/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 39: Train Loss = 0.1984 | Val Loss = 0.1892 | Val IoU = 0.7473
# Epoch 40/80: 100%|██████████| 170/170 [00:21<00:00,  7.89it/s]
# Epoch 40: Train Loss = 0.2014 | Val Loss = 0.1906 | Val IoU = 0.7521
# ------------>>> Best model saved <<<-------------
# Epoch 41/80: 100%|██████████| 170/170 [00:21<00:00,  7.84it/s]
# Epoch 41: Train Loss = 0.2048 | Val Loss = 0.1940 | Val IoU = 0.7503
# Epoch 42/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 42: Train Loss = 0.2077 | Val Loss = 0.1984 | Val IoU = 0.7441
# Epoch 43/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 43: Train Loss = 0.2109 | Val Loss = 0.2008 | Val IoU = 0.7499
# Epoch 44/80: 100%|██████████| 170/170 [00:21<00:00,  7.85it/s]
# Epoch 44: Train Loss = 0.2146 | Val Loss = 0.2027 | Val IoU = 0.7521
# Epoch 45/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 45: Train Loss = 0.2177 | Val Loss = 0.2071 | Val IoU = 0.7508
# Epoch 46/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 46: Train Loss = 0.2200 | Val Loss = 0.2111 | Val IoU = 0.7475
# Epoch 47/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 47: Train Loss = 0.2241 | Val Loss = 0.2137 | Val IoU = 0.7546
# ------------>>> Best model saved <<<-------------
# Epoch 48/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 48: Train Loss = 0.2263 | Val Loss = 0.2161 | Val IoU = 0.7536
# Epoch 49/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 49: Train Loss = 0.2295 | Val Loss = 0.2193 | Val IoU = 0.7520
# Epoch 50/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 50: Train Loss = 0.2363 | Val Loss = 0.2217 | Val IoU = 0.7533
# Epoch 51/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 51: Train Loss = 0.2366 | Val Loss = 0.2256 | Val IoU = 0.7496
# Epoch 52/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 52: Train Loss = 0.2379 | Val Loss = 0.2284 | Val IoU = 0.7526
# Epoch 53/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 53: Train Loss = 0.2421 | Val Loss = 0.2328 | Val IoU = 0.7465
# Epoch 54/80: 100%|██████████| 170/170 [00:21<00:00,  7.77it/s]
# Epoch 54: Train Loss = 0.2446 | Val Loss = 0.2354 | Val IoU = 0.7487
# >>> LR changed: 0.000025 → 0.000013
# Epoch 55/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 55: Train Loss = 0.2479 | Val Loss = 0.2356 | Val IoU = 0.7551
# ------------>>> Best model saved <<<-------------
# Epoch 56/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 56: Train Loss = 0.2488 | Val Loss = 0.2386 | Val IoU = 0.7551
# ------------>>> Best model saved <<<-------------
# Epoch 57/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 57: Train Loss = 0.2529 | Val Loss = 0.2431 | Val IoU = 0.7515
# Epoch 58/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 58: Train Loss = 0.2566 | Val Loss = 0.2461 | Val IoU = 0.7526
# Epoch 59/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 59: Train Loss = 0.2583 | Val Loss = 0.2489 | Val IoU = 0.7533
# Epoch 60/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 60: Train Loss = 0.2628 | Val Loss = 0.2510 | Val IoU = 0.7589
# ------------>>> Best model saved <<<-------------
# Epoch 61/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 61: Train Loss = 0.2659 | Val Loss = 0.2547 | Val IoU = 0.7549
# Epoch 62/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 62: Train Loss = 0.2664 | Val Loss = 0.2541 | Val IoU = 0.7584
# Epoch 63/80: 100%|██████████| 170/170 [00:21<00:00,  7.88it/s]
# Epoch 63: Train Loss = 0.2643 | Val Loss = 0.2553 | Val IoU = 0.7521
# Epoch 64/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 64: Train Loss = 0.2644 | Val Loss = 0.2554 | Val IoU = 0.7522
# Epoch 65/80: 100%|██████████| 170/170 [00:21<00:00,  7.92it/s]
# Epoch 65: Train Loss = 0.2641 | Val Loss = 0.2530 | Val IoU = 0.7589
# Epoch 66/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 66: Train Loss = 0.2653 | Val Loss = 0.2536 | Val IoU = 0.7558
# Epoch 67/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 67: Train Loss = 0.2634 | Val Loss = 0.2533 | Val IoU = 0.7564
# >>> LR changed: 0.000013 → 0.000006
# Epoch 68/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 68: Train Loss = 0.2623 | Val Loss = 0.2536 | Val IoU = 0.7550
# Epoch 69/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 69: Train Loss = 0.2634 | Val Loss = 0.2532 | Val IoU = 0.7566
# Epoch 70/80: 100%|██████████| 170/170 [00:21<00:00,  7.96it/s]
# Epoch 70: Train Loss = 0.2627 | Val Loss = 0.2531 | Val IoU = 0.7575
# Epoch 71/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 71: Train Loss = 0.2630 | Val Loss = 0.2538 | Val IoU = 0.7559
# Epoch 72/80: 100%|██████████| 170/170 [00:21<00:00,  7.97it/s]
# Epoch 72: Train Loss = 0.2618 | Val Loss = 0.2529 | Val IoU = 0.7572
# Epoch 73/80: 100%|██████████| 170/170 [00:21<00:00,  7.87it/s]
# Epoch 73: Train Loss = 0.2633 | Val Loss = 0.2530 | Val IoU = 0.7560
# Epoch 74/80: 100%|██████████| 170/170 [00:21<00:00,  7.93it/s]
# Epoch 74: Train Loss = 0.2625 | Val Loss = 0.2529 | Val IoU = 0.7567
# >>> LR changed: 0.000006 → 0.000003
# Epoch 75/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 75: Train Loss = 0.2605 | Val Loss = 0.2528 | Val IoU = 0.7571
# Epoch 76/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 76: Train Loss = 0.2615 | Val Loss = 0.2530 | Val IoU = 0.7568
# Epoch 77/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 77: Train Loss = 0.2604 | Val Loss = 0.2529 | Val IoU = 0.7562
# Epoch 78/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 78: Train Loss = 0.2607 | Val Loss = 0.2517 | Val IoU = 0.7597
# ------------>>> Best model saved <<<-------------
# Epoch 79/80: 100%|██████████| 170/170 [00:21<00:00,  7.95it/s]
# Epoch 79: Train Loss = 0.2617 | Val Loss = 0.2520 | Val IoU = 0.7606
# ------------>>> Best model saved <<<-------------
# Epoch 80/80: 100%|██████████| 170/170 [00:21<00:00,  7.94it/s]
# Epoch 80: Train Loss = 0.2611 | Val Loss = 0.2521 | Val IoU = 0.7587
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.7500
# FINAL TEST LOSS:: 0.2587
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
