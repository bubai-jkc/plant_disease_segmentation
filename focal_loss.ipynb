# %% [markdown]
# <a href="https://colab.research.google.com/github/bubai-jkc/plant_disease_segmentation/blob/main/focal_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 1. SETUP ---
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d fakhrealam9537/leaf-disease-segmentation-dataset

import zipfile, os, torch, torch.nn as nn, torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from tqdm import tqdm
import random

# Extract dataset
zip_ref = zipfile.ZipFile('/content/leaf-disease-segmentation-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# --- 2. CONFIG ---
DATASET_PATH = "/content/aug_data/aug_data"
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
LR = 1e-4
NUM_EPOCHS = 120
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# --- 3. DATASET ---
class LeafDataset(Dataset):
    def __init__(self, root, augment=False):
        self.img_dir = os.path.join(root, "images")
        self.mask_dir = os.path.join(root, "masks")
        self.files = sorted(os.listdir(self.img_dir))
        self.augment = augment
        self.norm = transforms.Normalize([0.485,0.456,0.406],
                                         [0.229,0.224,0.225])

    def __len__(self): return len(self.files)

    def __getitem__(self, idx):
        name = self.files[idx]
        img = Image.open(os.path.join(self.img_dir,name)).convert("RGB")
        mask = Image.open(os.path.join(self.mask_dir,name.replace(".jpg",".png"))).convert("L")

        img = img.resize(IMG_SIZE)
        mask = mask.resize(IMG_SIZE, resample=Image.NEAREST)

        if self.augment:
            if np.random.rand()>0.5:
                img = transforms.functional.hflip(img)
                mask = transforms.functional.hflip(mask)
            if np.random.rand()>0.5:
                img = transforms.functional.vflip(img)
                mask = transforms.functional.vflip(mask)

        img = transforms.ToTensor()(img)
        img = self.norm(img)
        mask = (transforms.ToTensor()(mask)>0).float()

        return img, mask

# --- 4. SPLIT ---
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

full_dataset = LeafDataset(DATASET_PATH)
total = len(full_dataset)

train_size = int(0.7 * total)
val_size = int(0.15 * total)

split_path = "/content/data_split.pt"

if os.path.exists(split_path):
    indices = torch.load(split_path)
    print("Loaded fixed split")
else:
    indices = torch.randperm(total)
    torch.save(indices, split_path)
    print("Saved new split")

train_idx = indices[:train_size]
val_idx = indices[train_size:train_size+val_size]
test_idx = indices[train_size+val_size:]

train_ds = torch.utils.data.Subset(LeafDataset(DATASET_PATH, True), train_idx)
val_ds   = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), val_idx)
test_ds  = torch.utils.data.Subset(LeafDataset(DATASET_PATH, False), test_idx)

pin = True if DEVICE.type == "cuda" else False

train_loader = DataLoader(train_ds, BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=pin)
val_loader   = DataLoader(val_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)
test_loader  = DataLoader(test_ds, BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=pin)

# --- 5. MODEL ---
class DoubleConv(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c,out_c,3,1,1,bias=False),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.net(x)

class Up(nn.Module):
    def __init__(self,in_c,skip_c,out_c):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_c,in_c//2,2,2)
        self.conv = DoubleConv(in_c//2+skip_c,out_c)

    def forward(self,x,skip):
        x = self.up(x)
        x = torch.cat([x,skip],1)
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        layers = list(base.children())

        self.init = nn.Sequential(*layers[:3])
        self.pool = layers[3]
        self.l1 = layers[4]
        self.l2 = layers[5]
        self.l3 = layers[6]
        self.l4 = layers[7]

        self.u1 = Up(2048,1024,512)
        self.u2 = Up(512,512,256)
        self.u3 = Up(256,256,128)
        self.u4 = Up(128,64,64)

        self.final = nn.Sequential(
            nn.ConvTranspose2d(64,32,2,2),
            nn.Conv2d(32,1,1)
        )

    def forward(self,x):
        x0 = self.init(x)
        x1 = self.l1(self.pool(x0))
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        x4 = self.l4(x3)

        d1 = self.u1(x4,x3)
        d2 = self.u2(d1,x2)
        d3 = self.u3(d2,x1)
        d4 = self.u4(d3,x0)

        return self.final(d4)

# --- 6. FOCAL LOSS ---
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.75, gamma=2, reduction='mean'):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        bce = F.binary_cross_entropy_with_logits(inputs, targets, reduction='none')
        pt = torch.exp(-bce)
        loss = self.alpha * (1 - pt) ** self.gamma * bce

        if self.reduction == 'mean':
            return loss.mean()
        elif self.reduction == 'sum':
            return loss.sum()
        else:
            return loss

def mean_iou(pred,mask):
    pred = (torch.sigmoid(pred)>0.5).float()
    inter = (pred*mask).sum((1,2,3))
    union = pred.sum((1,2,3)) + mask.sum((1,2,3)) - inter
    return ((inter+1e-6)/(union+1e-6)).mean()

# --- 7. TRAIN ---
model = UNet().to(DEVICE)
criterion = FocalLoss(alpha=0.75, gamma=2)
optimizer = optim.Adam(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='max',
    patience=7,
    factor=0.5
)

best_iou = 0
train_losses, val_losses = [], []
train_ious, val_ious = [], []

prev_lr = optimizer.param_groups[0]['lr']

for epoch in range(NUM_EPOCHS):
    model.train()
    train_loss, train_iou = 0,0
    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for x, y in loop:
        x,y = x.to(DEVICE), y.to(DEVICE)

        out = model(x)
        loss = criterion(out,y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_iou += mean_iou(out,y).item()

    model.eval()
    val_loss, val_iou = 0,0

    with torch.no_grad():
        for x,y in val_loader:
            x,y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)

            val_loss += criterion(out,y).item()
            val_iou += mean_iou(out,y).item()

    train_loss /= len(train_loader)
    val_loss /= len(val_loader)
    train_iou /= len(train_loader)
    val_iou /= len(val_loader)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_ious.append(train_iou)
    val_ious.append(val_iou)

    print(f"\nEpoch {epoch+1}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f} | Val IoU = {val_iou:.4f}")

    scheduler.step(val_iou)

    current_lr = optimizer.param_groups[0]['lr']
    if current_lr != prev_lr:
        print(f">>> LR changed: {prev_lr:.6f} → {current_lr:.6f}")
    prev_lr = current_lr

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_model.pth")
        print("------------>>> Best model saved <<<-------------\n")
# --- 8. PLOT GRAPHS ---
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")
plt.legend()
plt.title("Train Loss vs Validation Loss")

plt.subplot(1,2,2)
plt.plot(train_ious, label="Train IoU")
plt.plot(val_ious, label="Val IoU")
plt.legend()
plt.title("Train IoU vs Validation IoU")

plt.savefig("training_curves.png")
plt.show()

# --- 9. TEST ---
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

test_iou, test_loss = 0,0

with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)

        test_loss += criterion(out,y).item()
        test_iou += mean_iou(out,y).item()

avg_test_iou = test_iou / len(test_loader)
avg_test_loss = test_loss / len(test_loader)

print("\n\n---------------------------------")
print("---------------------------------")
print(f"\nFINAL TEST IoU:: {avg_test_iou:.4f}")
print(f"FINAL TEST LOSS:: {avg_test_loss:.4f}")
print("\n---------------------------------")
print("---------------------------------\n\n")

# --- 10. SAVE RESULTS ---
os.makedirs("all_test_results", exist_ok=True)
os.makedirs("sample_outputs", exist_ok=True)

idx, sample_count = 0,0
print("\n\nSome sample outputs:\n")
with torch.no_grad():
    for x,y in test_loader:
        x,y = x.to(DEVICE), y.to(DEVICE)
        out = model(x)
        pred = (torch.sigmoid(out)>0.5).float()

        for i in range(x.size(0)):
            iou = mean_iou(out[i].unsqueeze(0), y[i].unsqueeze(0)).item()

            img = x[i].cpu().permute(1,2,0).numpy()
            img = img*[0.229,0.224,0.225] + [0.485,0.456,0.406]
            img = np.clip(img,0,1)

            gt = y[i].cpu().squeeze().numpy()
            pr = pred[i].cpu().squeeze().numpy()

            # save all
            fig_all, ax_all = plt.subplots(1,3, figsize=(10,4))
            ax_all[0].imshow(img); ax_all[1].imshow(gt,cmap='gray'); ax_all[2].imshow(pr,cmap='gray')
            for a in ax_all: a.axis("off")
            plt.savefig(f"all_test_results/{idx}.png")
            plt.close()

            # show + save 20

            if sample_count < 20:
                error = np.abs(gt - pr)
                fig, ax = plt.subplots(1,4, figsize=(14,4))

                ax[0].imshow(img)
                ax[0].set_title("Image")

                ax[1].imshow(gt, cmap='gray')
                ax[1].set_title("Ground Truth")

                ax[2].imshow(pr, cmap='gray')
                ax[2].set_title(f"Prediction (IoU: {iou:.3f})")

                ax[3].imshow(error, cmap='hot')
                ax[3].set_title("Error Map")


                for a in ax: a.axis("off")

                plt.savefig(f"sample_outputs/{sample_count}.png")
                plt.show()

                sample_count += 1

            idx += 1

# --- 11. DOWNLOAD ---
# !zip -rq results_focal.zip all_test_results sample_outputs

from google.colab import files
files.download("results_focal.zip")
print("\n\n>>> Test images saved successfully using BEST model")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fakhrealam9537/leaf-disease-segmentation-dataset
# License(s): CC0-1.0
# Downloading leaf-disease-segmentation-dataset.zip to /content
# 100% 503M/503M [00:03<00:00, 176MB/s]
#
# Saved new split
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 195MB/s]
# Epoch 1/120: 100%|██████████| 258/258 [01:02<00:00,  4.11it/s]
# Epoch 1: Train Loss = 0.0597 | Val Loss = 0.0273 | Val IoU = 0.6270
# ------------>>> Best model saved <<<-------------
# Epoch 2/120: 100%|██████████| 258/258 [01:04<00:00,  4.03it/s]
# Epoch 2: Train Loss = 0.0289 | Val Loss = 0.0207 | Val IoU = 0.6949
# ------------>>> Best model saved <<<-------------
# Epoch 3/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 3: Train Loss = 0.0227 | Val Loss = 0.0220 | Val IoU = 0.7025
# ------------>>> Best model saved <<<-------------
# Epoch 4/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 4: Train Loss = 0.0203 | Val Loss = 0.0184 | Val IoU = 0.7373
# ------------>>> Best model saved <<<-------------
# Epoch 5/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 5: Train Loss = 0.0178 | Val Loss = 0.0179 | Val IoU = 0.7272
# Epoch 6/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 6: Train Loss = 0.0167 | Val Loss = 0.0159 | Val IoU = 0.7377
# ------------>>> Best model saved <<<-------------
# Epoch 7/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 7: Train Loss = 0.0159 | Val Loss = 0.0160 | Val IoU = 0.7509
# ------------>>> Best model saved <<<-------------
# Epoch 8/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 8: Train Loss = 0.0142 | Val Loss = 0.0156 | Val IoU = 0.7636
# ------------>>> Best model saved <<<-------------
# Epoch 9/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 9: Train Loss = 0.0139 | Val Loss = 0.0130 | Val IoU = 0.7802
# ------------>>> Best model saved <<<-------------
# Epoch 10/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 10: Train Loss = 0.0124 | Val Loss = 0.0124 | Val IoU = 0.7813
# ------------>>> Best model saved <<<-------------
# Epoch 11/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 11: Train Loss = 0.0116 | Val Loss = 0.0128 | Val IoU = 0.7887
# ------------>>> Best model saved <<<-------------
# Epoch 12/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 12: Train Loss = 0.0119 | Val Loss = 0.0124 | Val IoU = 0.7850
# Epoch 13/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 13: Train Loss = 0.0110 | Val Loss = 0.0122 | Val IoU = 0.7846
# Epoch 14/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 14: Train Loss = 0.0102 | Val Loss = 0.0116 | Val IoU = 0.7916
# ------------>>> Best model saved <<<-------------
# Epoch 15/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 15: Train Loss = 0.0101 | Val Loss = 0.0128 | Val IoU = 0.7866
# Epoch 16/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 16: Train Loss = 0.0111 | Val Loss = 0.0123 | Val IoU = 0.7914
# Epoch 17/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 17: Train Loss = 0.0113 | Val Loss = 0.0117 | Val IoU = 0.7943
# ------------>>> Best model saved <<<-------------
# Epoch 18/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 18: Train Loss = 0.0099 | Val Loss = 0.0110 | Val IoU = 0.8051
# ------------>>> Best model saved <<<-------------
# Epoch 19/120: 100%|██████████| 258/258 [01:05<00:00,  3.95it/s]
# Epoch 19: Train Loss = 0.0095 | Val Loss = 0.0112 | Val IoU = 0.8119
# ------------>>> Best model saved <<<-------------
# Epoch 20/120: 100%|██████████| 258/258 [01:06<00:00,  3.86it/s]
# Epoch 20: Train Loss = 0.0092 | Val Loss = 0.0105 | Val IoU = 0.8200
# ------------>>> Best model saved <<<-------------
# Epoch 21/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 21: Train Loss = 0.0090 | Val Loss = 0.0106 | Val IoU = 0.8192
# Epoch 22/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 22: Train Loss = 0.0090 | Val Loss = 0.0102 | Val IoU = 0.8198
# Epoch 23/120: 100%|██████████| 258/258 [01:07<00:00,  3.84it/s]
# Epoch 23: Train Loss = 0.0087 | Val Loss = 0.0104 | Val IoU = 0.8182
# Epoch 24/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 24: Train Loss = 0.0099 | Val Loss = 0.0112 | Val IoU = 0.8062
# Epoch 25/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 25: Train Loss = 0.0087 | Val Loss = 0.0099 | Val IoU = 0.8232
# ------------>>> Best model saved <<<-------------
# Epoch 26/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 26: Train Loss = 0.0086 | Val Loss = 0.0102 | Val IoU = 0.8260
# ------------>>> Best model saved <<<-------------
# Epoch 27/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 27: Train Loss = 0.0117 | Val Loss = 0.0107 | Val IoU = 0.8170
# Epoch 28/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 28: Train Loss = 0.0089 | Val Loss = 0.0098 | Val IoU = 0.8268
# ------------>>> Best model saved <<<-------------
# Epoch 29/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 29: Train Loss = 0.0086 | Val Loss = 0.0096 | Val IoU = 0.8279
# ------------>>> Best model saved <<<-------------
# Epoch 30/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 30: Train Loss = 0.0089 | Val Loss = 0.0095 | Val IoU = 0.8264
# Epoch 31/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 31: Train Loss = 0.0078 | Val Loss = 0.0094 | Val IoU = 0.8317
# ------------>>> Best model saved <<<-------------
# Epoch 32/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 32: Train Loss = 0.0076 | Val Loss = 0.0093 | Val IoU = 0.8341
# ------------>>> Best model saved <<<-------------
# Epoch 33/120: 100%|██████████| 258/258 [01:06<00:00,  3.88it/s]
# Epoch 33: Train Loss = 0.0074 | Val Loss = 0.0095 | Val IoU = 0.8338
# Epoch 34/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 34: Train Loss = 0.0072 | Val Loss = 0.0091 | Val IoU = 0.8383
# ------------>>> Best model saved <<<-------------
# Epoch 35/120: 100%|██████████| 258/258 [01:05<00:00,  3.95it/s]
# Epoch 35: Train Loss = 0.0070 | Val Loss = 0.0087 | Val IoU = 0.8433
# ------------>>> Best model saved <<<-------------
# Epoch 36/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 36: Train Loss = 0.0069 | Val Loss = 0.0091 | Val IoU = 0.8442
# ------------>>> Best model saved <<<-------------
# Epoch 37/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 37: Train Loss = 0.0068 | Val Loss = 0.0090 | Val IoU = 0.8414
# Epoch 38/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 38: Train Loss = 0.0077 | Val Loss = 0.0128 | Val IoU = 0.7946
# Epoch 39/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 39: Train Loss = 0.0099 | Val Loss = 0.0093 | Val IoU = 0.8331
# Epoch 40/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 40: Train Loss = 0.0076 | Val Loss = 0.0091 | Val IoU = 0.8401
# Epoch 41/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 41: Train Loss = 0.0070 | Val Loss = 0.0086 | Val IoU = 0.8480
# ------------>>> Best model saved <<<-------------
# Epoch 42/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 42: Train Loss = 0.0068 | Val Loss = 0.0094 | Val IoU = 0.8403
# Epoch 43/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 43: Train Loss = 0.0067 | Val Loss = 0.0085 | Val IoU = 0.8481
# ------------>>> Best model saved <<<-------------
# Epoch 44/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 44: Train Loss = 0.0065 | Val Loss = 0.0084 | Val IoU = 0.8496
# ------------>>> Best model saved <<<-------------
# Epoch 45/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 45: Train Loss = 0.0064 | Val Loss = 0.0081 | Val IoU = 0.8557
# ------------>>> Best model saved <<<-------------
# Epoch 46/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 46: Train Loss = 0.0062 | Val Loss = 0.0085 | Val IoU = 0.8487
# Epoch 47/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 47: Train Loss = 0.0062 | Val Loss = 0.0080 | Val IoU = 0.8568
# ------------>>> Best model saved <<<-------------
# Epoch 48/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 48: Train Loss = 0.0060 | Val Loss = 0.0080 | Val IoU = 0.8589
# ------------>>> Best model saved <<<-------------
# Epoch 49/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 49: Train Loss = 0.0060 | Val Loss = 0.0082 | Val IoU = 0.8530
# Epoch 50/120: 100%|██████████| 258/258 [01:06<00:00,  3.85it/s]
# Epoch 50: Train Loss = 0.0060 | Val Loss = 0.0083 | Val IoU = 0.8537
# Epoch 51/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 51: Train Loss = 0.0061 | Val Loss = 0.0115 | Val IoU = 0.8372
# Epoch 52/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 52: Train Loss = 0.0081 | Val Loss = 0.0093 | Val IoU = 0.8464
# Epoch 53/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 53: Train Loss = 0.0083 | Val Loss = 0.0092 | Val IoU = 0.8445
# Epoch 54/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 54: Train Loss = 0.0084 | Val Loss = 0.0091 | Val IoU = 0.8448
# Epoch 55/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 55: Train Loss = 0.0066 | Val Loss = 0.0084 | Val IoU = 0.8518
# Epoch 56/120: 100%|██████████| 258/258 [01:06<00:00,  3.87it/s]
# Epoch 56: Train Loss = 0.0062 | Val Loss = 0.0084 | Val IoU = 0.8558
# >>> LR changed: 0.000100 → 0.000050
# Epoch 57/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 57: Train Loss = 0.0058 | Val Loss = 0.0082 | Val IoU = 0.8593
# ------------>>> Best model saved <<<-------------
# Epoch 58/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 58: Train Loss = 0.0057 | Val Loss = 0.0080 | Val IoU = 0.8606
# ------------>>> Best model saved <<<-------------
# Epoch 59/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 59: Train Loss = 0.0056 | Val Loss = 0.0078 | Val IoU = 0.8642
# ------------>>> Best model saved <<<-------------
# Epoch 60/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 60: Train Loss = 0.0055 | Val Loss = 0.0079 | Val IoU = 0.8653
# ------------>>> Best model saved <<<-------------
# Epoch 61/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 61: Train Loss = 0.0062 | Val Loss = 0.0084 | Val IoU = 0.8624
# Epoch 62/120: 100%|██████████| 258/258 [01:07<00:00,  3.83it/s]
# Epoch 62: Train Loss = 0.0057 | Val Loss = 0.0080 | Val IoU = 0.8640
# Epoch 63/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 63: Train Loss = 0.0054 | Val Loss = 0.0079 | Val IoU = 0.8656
# ------------>>> Best model saved <<<-------------
# Epoch 64/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 64: Train Loss = 0.0052 | Val Loss = 0.0081 | Val IoU = 0.8665
# ------------>>> Best model saved <<<-------------
# Epoch 65/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 65: Train Loss = 0.0052 | Val Loss = 0.0077 | Val IoU = 0.8695
# ------------>>> Best model saved <<<-------------
# Epoch 66/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 66: Train Loss = 0.0051 | Val Loss = 0.0077 | Val IoU = 0.8709
# ------------>>> Best model saved <<<-------------
# Epoch 67/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 67: Train Loss = 0.0051 | Val Loss = 0.0076 | Val IoU = 0.8706
# Epoch 68/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 68: Train Loss = 0.0050 | Val Loss = 0.0077 | Val IoU = 0.8723
# ------------>>> Best model saved <<<-------------
# Epoch 69/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 69: Train Loss = 0.0050 | Val Loss = 0.0077 | Val IoU = 0.8710
# Epoch 70/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 70: Train Loss = 0.0049 | Val Loss = 0.0077 | Val IoU = 0.8744
# ------------>>> Best model saved <<<-------------
# Epoch 71/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 71: Train Loss = 0.0048 | Val Loss = 0.0076 | Val IoU = 0.8742
# Epoch 72/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 72: Train Loss = 0.0048 | Val Loss = 0.0075 | Val IoU = 0.8763
# ------------>>> Best model saved <<<-------------
# Epoch 73/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 73: Train Loss = 0.0048 | Val Loss = 0.0074 | Val IoU = 0.8781
# ------------>>> Best model saved <<<-------------
# Epoch 74/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 74: Train Loss = 0.0047 | Val Loss = 0.0074 | Val IoU = 0.8777
# Epoch 75/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 75: Train Loss = 0.0047 | Val Loss = 0.0076 | Val IoU = 0.8776
# Epoch 76/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 76: Train Loss = 0.0047 | Val Loss = 0.0073 | Val IoU = 0.8796
# ------------>>> Best model saved <<<-------------
# Epoch 77/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 77: Train Loss = 0.0048 | Val Loss = 0.0081 | Val IoU = 0.8739
# Epoch 78/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 78: Train Loss = 0.0048 | Val Loss = 0.0077 | Val IoU = 0.8773
# Epoch 79/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 79: Train Loss = 0.0046 | Val Loss = 0.0079 | Val IoU = 0.8773
# Epoch 80/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 80: Train Loss = 0.0047 | Val Loss = 0.0079 | Val IoU = 0.8793
# Epoch 81/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 81: Train Loss = 0.0045 | Val Loss = 0.0079 | Val IoU = 0.8800
# ------------>>> Best model saved <<<-------------
# Epoch 82/120: 100%|██████████| 258/258 [01:06<00:00,  3.88it/s]
# Epoch 82: Train Loss = 0.0046 | Val Loss = 0.0078 | Val IoU = 0.8767
# Epoch 83/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 83: Train Loss = 0.0045 | Val Loss = 0.0076 | Val IoU = 0.8813
# ------------>>> Best model saved <<<-------------
# Epoch 84/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 84: Train Loss = 0.0045 | Val Loss = 0.0078 | Val IoU = 0.8802
# Epoch 85/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 85: Train Loss = 0.0046 | Val Loss = 0.0077 | Val IoU = 0.8795
# Epoch 86/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 86: Train Loss = 0.0044 | Val Loss = 0.0077 | Val IoU = 0.8827
# ------------>>> Best model saved <<<-------------
# Epoch 87/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 87: Train Loss = 0.0044 | Val Loss = 0.0073 | Val IoU = 0.8839
# ------------>>> Best model saved <<<-------------
# Epoch 88/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 88: Train Loss = 0.0043 | Val Loss = 0.0071 | Val IoU = 0.8846
# ------------>>> Best model saved <<<-------------
# Epoch 89/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 89: Train Loss = 0.0042 | Val Loss = 0.0076 | Val IoU = 0.8828
# Epoch 90/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 90: Train Loss = 0.0043 | Val Loss = 0.0073 | Val IoU = 0.8859
# ------------>>> Best model saved <<<-------------
# Epoch 91/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 91: Train Loss = 0.0041 | Val Loss = 0.0072 | Val IoU = 0.8869
# ------------>>> Best model saved <<<-------------
# Epoch 92/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 92: Train Loss = 0.0041 | Val Loss = 0.0071 | Val IoU = 0.8876
# ------------>>> Best model saved <<<-------------
# Epoch 93/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 93: Train Loss = 0.0041 | Val Loss = 0.0074 | Val IoU = 0.8864
# Epoch 94/120: 100%|██████████| 258/258 [01:05<00:00,  3.91it/s]
# Epoch 94: Train Loss = 0.0042 | Val Loss = 0.0071 | Val IoU = 0.8874
# Epoch 95/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 95: Train Loss = 0.0041 | Val Loss = 0.0071 | Val IoU = 0.8893
# ------------>>> Best model saved <<<-------------
# Epoch 96/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 96: Train Loss = 0.0040 | Val Loss = 0.0071 | Val IoU = 0.8894
# ------------>>> Best model saved <<<-------------
# Epoch 97/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 97: Train Loss = 0.0040 | Val Loss = 0.0072 | Val IoU = 0.8861
# Epoch 98/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 98: Train Loss = 0.0040 | Val Loss = 0.0079 | Val IoU = 0.8860
# Epoch 99/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 99: Train Loss = 0.0043 | Val Loss = 0.0075 | Val IoU = 0.8842
# Epoch 100/120: 100%|██████████| 258/258 [01:05<00:00,  3.95it/s]
# Epoch 100: Train Loss = 0.0053 | Val Loss = 0.0072 | Val IoU = 0.8809
# Epoch 101/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 101: Train Loss = 0.0041 | Val Loss = 0.0072 | Val IoU = 0.8849
# Epoch 102/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 102: Train Loss = 0.0040 | Val Loss = 0.0071 | Val IoU = 0.8883
# Epoch 103/120: 100%|██████████| 258/258 [01:05<00:00,  3.93it/s]
# Epoch 103: Train Loss = 0.0039 | Val Loss = 0.0073 | Val IoU = 0.8886
# Epoch 104/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 104: Train Loss = 0.0038 | Val Loss = 0.0071 | Val IoU = 0.8914
# ------------>>> Best model saved <<<-------------
# Epoch 105/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 105: Train Loss = 0.0038 | Val Loss = 0.0073 | Val IoU = 0.8892
# Epoch 106/120: 100%|██████████| 258/258 [01:06<00:00,  3.91it/s]
# Epoch 106: Train Loss = 0.0038 | Val Loss = 0.0070 | Val IoU = 0.8920
# ------------>>> Best model saved <<<-------------
# Epoch 107/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 107: Train Loss = 0.0037 | Val Loss = 0.0069 | Val IoU = 0.8933
# ------------>>> Best model saved <<<-------------
# Epoch 108/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 108: Train Loss = 0.0037 | Val Loss = 0.0072 | Val IoU = 0.8922
# Epoch 109/120: 100%|██████████| 258/258 [01:06<00:00,  3.90it/s]
# Epoch 109: Train Loss = 0.0037 | Val Loss = 0.0071 | Val IoU = 0.8919
# Epoch 110/120: 100%|██████████| 258/258 [01:06<00:00,  3.88it/s]
# Epoch 110: Train Loss = 0.0037 | Val Loss = 0.0070 | Val IoU = 0.8926
# Epoch 111/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 111: Train Loss = 0.0037 | Val Loss = 0.0070 | Val IoU = 0.8945
# ------------>>> Best model saved <<<-------------
# Epoch 112/120: 100%|██████████| 258/258 [01:05<00:00,  3.95it/s]
# Epoch 112: Train Loss = 0.0037 | Val Loss = 0.0069 | Val IoU = 0.8940
# Epoch 113/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 113: Train Loss = 0.0038 | Val Loss = 0.0073 | Val IoU = 0.8926
# Epoch 114/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 114: Train Loss = 0.0038 | Val Loss = 0.0068 | Val IoU = 0.8927
# Epoch 115/120: 100%|██████████| 258/258 [01:06<00:00,  3.89it/s]
# Epoch 115: Train Loss = 0.0037 | Val Loss = 0.0072 | Val IoU = 0.8936
# Epoch 116/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 116: Train Loss = 0.0037 | Val Loss = 0.0070 | Val IoU = 0.8952
# ------------>>> Best model saved <<<-------------
# Epoch 117/120: 100%|██████████| 258/258 [01:05<00:00,  3.95it/s]
# Epoch 117: Train Loss = 0.0037 | Val Loss = 0.0068 | Val IoU = 0.8959
# ------------>>> Best model saved <<<-------------
# Epoch 118/120: 100%|██████████| 258/258 [01:06<00:00,  3.88it/s]
# Epoch 118: Train Loss = 0.0037 | Val Loss = 0.0069 | Val IoU = 0.8963
# ------------>>> Best model saved <<<-------------
# Epoch 119/120: 100%|██████████| 258/258 [01:05<00:00,  3.92it/s]
# Epoch 119: Train Loss = 0.0036 | Val Loss = 0.0069 | Val IoU = 0.8958
# Epoch 120/120: 100%|██████████| 258/258 [01:05<00:00,  3.94it/s]
# Epoch 120: Train Loss = 0.0035 | Val Loss = 0.0068 | Val IoU = 0.8967
# ------------>>> Best model saved <<<-------------
# ---------------------------------
# ---------------------------------
#
# FINAL TEST IoU:: 0.9070
# FINAL TEST LOSS:: 0.0062
#
# ---------------------------------
# ---------------------------------
#
#
#
#
# Some sample outputs:
# >>> Test images saved successfully using BEST model
